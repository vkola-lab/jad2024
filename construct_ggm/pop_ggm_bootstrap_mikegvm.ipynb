# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob 
import os
import warnings
import networkx as nx
import matplotlib.colors as mcolors
warnings.simplefilter(action='ignore', category=FutureWarning)
from scipy.stats import pearsonr
from sklearn.covariance import GraphicalLassoCV
from networkx.generators.community import gaussian_random_partition_graph
import scipy.stats as stats
from scipy.stats import ttest_ind
import nibabel as nib 
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm
pd.options.display.max_rows = None
pd.options.display.max_columns = None
import glob as glob
import math


#set random generator outside loop 
#seed everytrhing once at begibning and dont touch it 
np.random.seed(3)

# %%
#all adni and nacc patients 
comb_gmv = pd.read_csv("/data2/MRI_PET_DATA/graph/csvs/graph_gmv_volumes/parcellation_volumes_raw.csv")

# %%
#read in adni prog and adni stab for bootstrapping (these ones have already been normalized)
adni_gmv_prog_lr = pd.read_csv("/data2/MRI_PET_DATA/graph/csvs/graph_gmv_volumes/mike_gmv_adni_prog_norm.csv")
adni_gmv_stab_lr = pd.read_csv('/data2/MRI_PET_DATA/graph/csvs/graph_gmv_volumes/mike_gmv_adni_stab_norm.csv')
# print(adni_gmv_prog)
print(adni_gmv_stab_lr.columns)
# Out:
# Index(['RID', 'TIV', 'vol_l3thVen', 'vol_r3thVen', 'vol_l4thVen',
#        'vol_r4thVen', 'vol_lAcc', 'vol_rAcc', 'vol_lAmy', 'vol_rAmy',
#        ...
#        'vol_rSupParLo', 'vol_lSupTemGy', 'vol_rSupTemGy', 'vol_lTemPo',
#        'vol_rTemPo', 'vol_lInfFroAngGy', 'vol_rInfFroAngGy', 'vol_lTemTraGy',
#        'vol_rTemTraGy', 'Dataset'],
#       dtype='object', length=145)

# %%
#drop regions with 0 volume 
adni_gmv_prog_lr = adni_gmv_prog_lr.drop(['vol_lInfLatVen','vol_rInfLatVen','vol_lOC','vol_rOC'], axis=1)
adni_gmv_stab_lr = adni_gmv_stab_lr.drop(['vol_lInfLatVen','vol_rInfLatVen','vol_lOC','vol_rOC'],axis=1)

# %%
# adni_gmv_prog.isna().sum()
#drop regions with 0 volume 
# 25 vol_lInfLatVen       154
# 26 vol_rInfLatVen         8
#37 vol_lOC              154
# 38 vol_rOC                1
#no more zero values 
zero_present = (adni_gmv_stab_lr == 0).any().any()
print(zero_present)
# zero_counts = (adni_gmv_prog == 0).sum()
# print(zero_counts)
# Out:
# False

# %%
#I think for graph now I need to drop all the cols like RID, TIV, 'Dataset'
adni_gmv_prog_lr = adni_gmv_prog_lr.drop(['RID','TIV','Dataset'], axis=1)
adni_gmv_stab_lr = adni_gmv_stab_lr.drop(['RID','TIV','Dataset'], axis=1)

# %%
print(adni_gmv_prog_lr)
# Out:
#      vol_l3thVen  vol_r3thVen  vol_l4thVen  vol_r4thVen  vol_lAcc  vol_rAcc  \
# 0       0.000027     0.000029     0.000025     0.000027  0.000218  0.000214
# 1       0.000012     0.000008     0.000030     0.000039  0.000225  0.000225
# 2       0.000016     0.000010     0.000047     0.000038  0.000215  0.000224
# 3       0.000018     0.000022     0.000057     0.000074  0.000195  0.000199
# 4       0.000036     0.000022     0.000055     0.000065  0.000314  0.000289
# 5       0.000017     0.000008     0.000052     0.000048  0.000197  0.000214
# 86           0.001868       0.000741       0.000589
# 87           0.001868       0.000832       0.000550
# 88           0.002656       0.001010       0.000887
# 89           0.001975       0.000913       0.000945
# 90           0.001592       0.000461       0.000499
# 91           0.001751       0.000792       0.000657
# 92           0.001903       0.000807       0.000841
# 93           0.001892       0.000866       0.000590
# 94           0.001562       0.000542       0.000495
# 95           0.002160       0.000972       0.000745
# 96           0.002321       0.000639       0.000596
# 97           0.001558       0.000529       0.000555
# 98           0.002038       0.000681       0.000688
# 99           0.001792       0.000676       0.000705
# 100          0.002102       0.000688       0.000500
# 101          0.002064       0.000816       0.000590
# 102          0.001941       0.000818       0.000758
# 103          0.002037       0.000904       0.000774
# 104          0.001823       0.000822       0.000635
# 105          0.001228       0.000734       0.000785
# 106          0.002116       0.000988       0.000805
# 107          0.002021       0.000734       0.000620
# 108          0.001959       0.000856       0.000790
# 109          0.001833       0.000696       0.000641
# 110          0.001508       0.000520       0.000509
# 111          0.001698       0.000690       0.000642
# 112          0.001913       0.000785       0.000605
# 113          0.001554       0.000453       0.000498
# 114          0.002334       0.000718       0.000677
# 115          0.002089       0.000528       0.000536
# 116          0.002150       0.000830       0.000818
# 117          0.002351       0.000642       0.000716
# 118          0.002098       0.001044       0.000793
# 119          0.002134       0.000916       0.000666
# 120          0.001448       0.000645       0.000567
# 121          0.001882       0.000597       0.000588
# 122          0.001466       0.000591       0.000597
# 123          0.001615       0.000590       0.000609
# 124          0.001494       0.000617       0.000644
# 125          0.002453       0.001053       0.000766
# 126          0.001898       0.000666       0.000579
# 127          0.001868       0.000541       0.000504
# 128          0.002213       0.000925       0.000629
# 129          0.001942       0.000618       0.000616
# 130          0.002346       0.000605       0.000591
# 131          0.001801       0.000920       0.000750
# 132          0.001740       0.000574       0.000394
# 133          0.001783       0.000424       0.000419
# 134          0.001963       0.000688       0.000429
# 135          0.001941       0.000754       0.000632
# 136          0.002017       0.000801       0.000556
# 137          0.001593       0.000841       0.000571
# 138          0.002088       0.000825       0.000757
# 139          0.001879       0.000740       0.000614
# 140          0.001810       0.000625       0.000515
# 141          0.001995       0.000809       0.000738
# 142          0.001994       0.000827       0.000735
# 143          0.001942       0.000689       0.000648
# 144          0.002071       0.000698       0.000626
# 145          0.001630       0.000434       0.000504
# 146          0.001377       0.000562       0.000528
# 147          0.001665       0.000767       0.000685
# 148          0.002081       0.000921       0.000725
# 149          0.001390       0.000920       0.000609
# 150          0.002178       0.000723       0.000547
# 151          0.001691       0.000455       0.000471
# 152          0.001502       0.000693       0.000758
# 153          0.001710       0.000689       0.000530

# %%
#function that combines the left and right volumes for an region 

def combine_regions(input_df):
    # Assuming the region names can be extracted from the column names
    regions = set(col.split('_')[1][1:] for col in input_df.columns if col.startswith('vol_'))

    # Dictionary to hold the sum of the left and right volumes for each region
    comb_regions = {}

    # Iterate through each region, summing the left and right volumes
    for region in regions:
        left_col = f'vol_l{region}'
        right_col = f'vol_r{region}'
        sum_col = f'vol_{region}'
        comb_regions[sum_col] = input_df[left_col] + input_df[right_col]

    # Create a new DataFrame using the dictionary
    combined_df = pd.DataFrame(comb_regions)
    
    return combined_df

# Usage:


adni_gmv_prog = combine_regions(adni_gmv_prog_lr)
adni_gmv_stab = combine_regions(adni_gmv_stab_lr)
print(adni_gmv_stab.columns)
# Out:
# Index(['vol_AngGy', 'vol_FroOpe', 'vol_TemTraGy', 'vol_Bst', 'vol_4thVen',
#        'vol_SupFroGy', 'vol_SupMarGy', 'vol_InfTemGy', 'vol_Cal+Cbr',
#        'vol_Amy', 'vol_SupMedFroGy', 'vol_InfFroGy', 'vol_ParOpe', 'vol_Acc',
#        'vol_Pal', 'vol_TemPo', 'vol_CbeLoCbe8-10', 'vol_Cun', 'vol_MidOccGy',
#        'vol_LinGy', 'vol_LatVen', 'vol_OccPo', 'vol_SCA', 'vol_ExtCbe',
#        'vol_ThaPro', 'vol_Cbr+Mot', 'vol_MedFroCbr', 'vol_OccFusGy',
#        'vol_PrcGy', 'vol_PosCinGy', 'vol_CbeLoCbe6-7', 'vol_BasCbr+FobBr',
#        'vol_Pla', 'vol_LatOrbGy', 'vol_InfOccGy', 'vol_MedPrcGy',
#        'vol_MidTemGy', 'vol_Hip', 'vol_FusGy', 'vol_CbeLoCbe1-5',
#        'vol_AntCinGy', 'vol_PCu', 'vol_MidCinGy', 'vol_ParHipGy', 'vol_Tem',
#        'vol_PosOrbGy', 'vol_AntOrbGy', 'vol_RecGy', 'vol_SupOccGy',
#        'vol_CenOpe', 'vol_InfFroAngGy', 'vol_3thVen', 'vol_MedOrbGy',
#        'vol_SupParLo', 'vol_CSF', 'vol_VenVen', 'vol_FroPo', 'vol_MedPoCGy',
#        'vol_PosIns', 'vol_SupTemGy', 'vol_Cau', 'vol_InfFroOrbGy', 'vol_CbrWM',
#        'vol_Ent', 'vol_Put', 'vol_PoCGy', 'vol_CbeWM', 'vol_AntIns',
#        'vol_MidFroGy'],
#       dtype='object')

# %%
#I guess scale the data like from original code because it involves distance metric 
#have to do standard scalar normalization 
#it normalizes by column 
#sklearn standard scalar 
scaler = StandardScaler()
#fit to your data and apply the transformation to your data 
progs_norm = scaler.fit_transform(adni_gmv_prog)
stable_norm = scaler.fit_transform(adni_gmv_stab)
print(progs_norm.shape)
print(progs_norm)
# Out:
# (154, 69)
# [[-0.12877457 -1.09265133 -0.71627722 ... -0.69064326 -1.02130627
#   -0.88439384]
#  [-0.44300192 -0.43757939  0.01827639 ... -0.25615879  0.13918647
#   -1.49881677]
#  [ 1.74626793 -0.88254723 -0.54341179 ... -0.21682318 -0.95721724
#    0.80304115]
#  ...
#  [-0.29184077 -2.50458269 -1.77477073 ... -1.71355495 -2.00784354
#   -0.83717037]
#  [ 0.17700823 -0.97023598  0.47274065 ...  0.67196266 -1.00351619
#   -0.04485185]
#  [-0.44371105 -0.03541565 -0.52335329 ... -0.8993846  -0.84470807
#    0.0654267 ]]

# %%
#the output of standard scaler is a numpy array so need to reconvert it 
progs_norm = pd.DataFrame(progs_norm, columns=adni_gmv_prog.columns)
stable_norm = pd.DataFrame(stable_norm,columns=adni_gmv_stab.columns)
print(progs_norm.columns)
# Out:
# Index(['vol_AngGy', 'vol_FroOpe', 'vol_TemTraGy', 'vol_Bst', 'vol_4thVen',
#        'vol_SupFroGy', 'vol_SupMarGy', 'vol_InfTemGy', 'vol_Cal+Cbr',
#        'vol_Amy', 'vol_SupMedFroGy', 'vol_InfFroGy', 'vol_ParOpe', 'vol_Acc',
#        'vol_Pal', 'vol_TemPo', 'vol_CbeLoCbe8-10', 'vol_Cun', 'vol_MidOccGy',
#        'vol_LinGy', 'vol_LatVen', 'vol_OccPo', 'vol_SCA', 'vol_ExtCbe',
#        'vol_ThaPro', 'vol_Cbr+Mot', 'vol_MedFroCbr', 'vol_OccFusGy',
#        'vol_PrcGy', 'vol_PosCinGy', 'vol_CbeLoCbe6-7', 'vol_BasCbr+FobBr',
#        'vol_Pla', 'vol_LatOrbGy', 'vol_InfOccGy', 'vol_MedPrcGy',
#        'vol_MidTemGy', 'vol_Hip', 'vol_FusGy', 'vol_CbeLoCbe1-5',
#        'vol_AntCinGy', 'vol_PCu', 'vol_MidCinGy', 'vol_ParHipGy', 'vol_Tem',
#        'vol_PosOrbGy', 'vol_AntOrbGy', 'vol_RecGy', 'vol_SupOccGy',
#        'vol_CenOpe', 'vol_InfFroAngGy', 'vol_3thVen', 'vol_MedOrbGy',
#        'vol_SupParLo', 'vol_CSF', 'vol_VenVen', 'vol_FroPo', 'vol_MedPoCGy',
#        'vol_PosIns', 'vol_SupTemGy', 'vol_Cau', 'vol_InfFroOrbGy', 'vol_CbrWM',
#        'vol_Ent', 'vol_Put', 'vol_PoCGy', 'vol_CbeWM', 'vol_AntIns',
#        'vol_MidFroGy'],
#       dtype='object')

# %%
progs_norm.isna().any().any()
# Out:
# False

# %%
#run bootstrapping (with replacement) before the graphical lasso cv () 
#random_state = None means random number generator is inistalized, produces different set of rnadom samples each time 
#setting random state to 1 so that its reproducable 

num_bootstrap_samples = 100
bootstrap_precision_matrices = []
bootstrap_samples = []
for x in range(num_bootstrap_samples):
    #sample with replacement, randomstate =1 for reporoducibility 
    bootstrap_sample = progs_norm.sample(n=len(progs_norm),replace=True)
    #append resamples df to a list 
    bootstrap_samples.append(bootstrap_sample)

# %%
#debugging error messages 
#check for infinite values 
print(np.any(np.isinf(bootstrap_samples)))
#check datatypes 
   #if I give it alphas [1,10] it looks like it drops almost all of the connections
# Out:
# False

# %%
# how I can be evaluating how well my model is fitting the data?


#2 matrices estimates (from graphical lasso and then the actual empirical)
#to do difference you could 
#

# %%
# if I just want estimate of how well its performing 
#

# %%
bootstrap_sample.isna().any().any()
# Out:
# False

# %%
from sklearn.covariance import GraphicalLasso

# %%
bootstrap_sample.corr()
# Out:
#                   vol_AngGy  vol_FroOpe  vol_TemTraGy   vol_Bst  vol_4thVen  \
# vol_AngGy          1.000000    0.489723      0.209163  0.077595    0.281131
# vol_FroOpe         0.489723    1.000000      0.458884 -0.026024    0.243992
# vol_TemTraGy       0.209163    0.458884      1.000000 -0.194857    0.298652
# vol_Bst            0.077595   -0.026024     -0.194857  1.000000    0.066167
# vol_CenOpe        0.466096  0.493901   0.708180   0.492847    0.650730
# vol_InfFroAngGy   0.300385  0.486275   0.568055   0.239044    0.601505
# vol_3thVen        0.517022  0.455217   0.440445   0.522701    0.493055
# vol_MedOrbGy      0.426364  0.416660   0.662343   0.235075    0.624849
# vol_SupParLo      0.322909  0.351786   0.610061   0.398607    0.248923
# vol_CSF           0.094901  0.126421  -0.010829   0.181047   -0.005947
# vol_VenVen        0.641673  0.515694   0.438800   0.505404    0.669279
# vol_FroPo         0.224578  0.309649   0.531929   0.105239    0.398715
# vol_MedPoCGy      0.201895  0.283184   0.582624   0.176585    0.268147
# vol_PosIns        0.535312  0.597988   0.428537   0.369566    0.798509
# vol_SupTemGy      0.428756  0.310256   0.566600   0.527485    0.542027
# vol_Cau           0.199987  0.669500   0.282450   0.190269    0.476860
# vol_InfFroOrbGy   0.308562  0.405414   0.514302   0.240786    0.522717
# vol_CbrWM        -0.024374  0.341976   0.010309  -0.032550    0.186102
# vol_Ent           1.000000  0.331807   0.265719   0.368274    0.520050
# vol_Put           0.331807  1.000000   0.342490   0.322171    0.618704
# vol_PoCGy         0.265719  0.342490   1.000000   0.315344    0.423549
# vol_CbeWM         0.368274  0.322171   0.315344   1.000000    0.406278
# vol_AntIns        0.520050  0.618704   0.423549   0.406278    1.000000
# vol_MidFroGy      0.232999  0.403208   0.621134   0.275320    0.503404
#
#                   vol_MidFroGy
# vol_AngGy             0.569609
# vol_FroOpe            0.702346
# vol_TemTraGy          0.411087
# vol_Bst              -0.116541
# vol_4thVen            0.247799
# vol_SupFroGy          0.733780
# vol_SupMarGy          0.583527
# vol_InfTemGy          0.491934
# vol_Cal+Cbr           0.468476
# vol_Amy               0.283117
# vol_SupMedFroGy       0.805921
# vol_InfFroGy          0.650781
# vol_ParOpe            0.532795
# vol_Acc               0.549978
# vol_Pal              -0.120031
# vol_TemPo             0.408725
# vol_CbeLoCbe8-10      0.283691
# vol_Cun               0.583616
# vol_MidOccGy          0.444810
# vol_LinGy             0.510557
# vol_LatVen            0.437584
# vol_OccPo             0.357369
# vol_SCA               0.452130
# vol_ExtCbe            0.379710
# vol_ThaPro            0.568962
# vol_Cbr+Mot           0.627359
# vol_MedFroCbr         0.586365
# vol_OccFusGy          0.484000
# vol_PrcGy             0.676433
# vol_PosCinGy          0.629803
# vol_CbeLoCbe6-7       0.218240
# vol_BasCbr+FobBr      0.549321
# vol_Pla               0.505740
# vol_LatOrbGy          0.633653
# vol_InfOccGy          0.516740
# vol_MedPrcGy          0.556695
# vol_MidTemGy          0.660614
# vol_Hip               0.347007
# vol_FusGy             0.428086
# vol_CbeLoCbe1-5       0.037019
# vol_AntCinGy          0.675222
# vol_PCu               0.683925
# vol_MidCinGy          0.696642
# vol_ParHipGy          0.270803
# vol_Tem               0.640307
# vol_PosOrbGy          0.501231
# vol_AntOrbGy          0.715109
# vol_RecGy             0.599497
# vol_SupOccGy          0.457237
# vol_CenOpe            0.657712
# vol_InfFroAngGy       0.717924
# vol_3thVen            0.472882
# vol_MedOrbGy          0.659436
# vol_SupParLo          0.446404
# vol_CSF              -0.041308
# vol_VenVen            0.317651
# vol_FroPo             0.613522
# vol_MedPoCGy          0.448689
# vol_PosIns            0.484372
# vol_SupTemGy          0.605098
# vol_Cau               0.423113
# vol_InfFroOrbGy       0.561948
# vol_CbrWM             0.211783
# vol_Ent               0.232999
# vol_Put               0.403208
# vol_PoCGy             0.621134
# vol_CbeWM             0.275320
# vol_AntIns            0.503404
# vol_MidFroGy          1.000000

# %%
# model = GraphicalLasso(alpha=0.1,max_iter=150, tol=1e-4, mode='lars',assume_centered=True) #if I predefine an alpha it will take less time 
# model.fit(bootstrap_sample)

# %%
#run graphical model on bootstrapped sample 
#find score on each num bootstrap sample 
#
models = []
for bootstrap_sample in tqdm(bootstrap_samples):
    model = GraphicalLassoCV(cv=5, max_iter=150, tol=1e-4) #if I predefine an alpha it will take less time 
    model.fit(bootstrap_sample)
    models.append(model)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   1%|          | 1/100 [00:06<10:10,  6.16s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   2%|▏         | 2/100 [00:11<09:21,  5.73s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   3%|▎         | 3/100 [00:17<09:28,  5.86s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   4%|▍         | 4/100 [00:23<09:37,  6.02s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   5%|▌         | 5/100 [00:30<09:43,  6.14s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   6%|▌         | 6/100 [00:35<09:05,  5.81s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   7%|▋         | 7/100 [00:42<09:26,  6.09s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/mlauber/mci_mri_graph/construct_ggm/pop_ggm_bootstrap_mikegvm.ipynb Cell 20 in 7
#       <a href='vscode-notebook-cell://ssh-remote%2Becho.bumc.bu.edu/home/mlauber/mci_mri_graph/construct_ggm/pop_ggm_bootstrap_mikegvm.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> for bootstrap_sample in tqdm(bootstrap_samples):
#       <a href='vscode-notebook-cell://ssh-remote%2Becho.bumc.bu.edu/home/mlauber/mci_mri_graph/construct_ggm/pop_ggm_bootstrap_mikegvm.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     model = GraphicalLassoCV(cv=5, max_iter=150, tol=1e-4) #if I predefine an alpha it will take less time
# ----> <a href='vscode-notebook-cell://ssh-remote%2Becho.bumc.bu.edu/home/mlauber/mci_mri_graph/construct_ggm/pop_ggm_bootstrap_mikegvm.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     model.fit(bootstrap_sample)
#       <a href='vscode-notebook-cell://ssh-remote%2Becho.bumc.bu.edu/home/mlauber/mci_mri_graph/construct_ggm/pop_ggm_bootstrap_mikegvm.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     models.append(model)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:893, in GraphicalLassoCV.fit(self, X, y)
#     887     warnings.simplefilter("ignore", ConvergenceWarning)
#     888     # Compute the cross-validated loss on the current grid
#     889
#     890     # NOTE: Warm-restarting graphical_lasso_path has been tried,
#     891     # and this did not allow to gain anything
#     892     # (same execution time with or without).
# --> 893     this_path = Parallel(n_jobs=self.n_jobs, verbose=self.verbose)(
#     894         delayed(graphical_lasso_path)(
#     895             X[train],
#     896             alphas=alphas,
#     897             X_test=X[test],
#     898             mode=self.mode,
#     899             tol=self.tol,
#     900             enet_tol=self.enet_tol,
#     901             max_iter=int(0.1 * self.max_iter),
#     902             verbose=inner_verbose,
#     903         )
#     904         for train, test in cv.split(X, y)
#     905     )
#     907 # Little danse to transform the list in what we need
#     908 covs, _, scores = zip(*this_path)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/utils/parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:589, in graphical_lasso_path(X, alphas, cov_init, X_test, mode, tol, enet_tol, max_iter, verbose)
#     586 for alpha in alphas:
#     587     try:
#     588         # Capture the errors, and move on
# --> 589         covariance_, precision_ = graphical_lasso(
#     590             emp_cov,
#     591             alpha=alpha,
#     592             cov_init=covariance_,
#     593             mode=mode,
#     594             tol=tol,
#     595             enet_tol=enet_tol,
#     596             max_iter=max_iter,
#     597             verbose=inner_verbose,
#     598         )
#     599         covariances_.append(covariance_)
#     600         precisions_.append(precision_)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:257, in graphical_lasso(emp_cov, alpha, cov_init, mode, tol, enet_tol, max_iter, verbose, return_costs, eps, return_n_iter)
#     244         coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
#     245             coefs,
#     246             alpha,
#    (...)
#     254             False,
#     255         )
#     256     else:  # mode == "lars"
# --> 257         _, _, coefs = lars_path_gram(
#     258             Xy=row,
#     259             Gram=sub_covariance,
#     260             n_samples=row.size,
#     261             alpha_min=alpha / (n_features - 1),
#     262             copy_Gram=True,
#     263             eps=eps,
#     264             method="lars",
#     265             return_path=False,
#     266         )
#     267 # Update the precision matrix
#     268 precision_[idx, idx] = 1.0 / (
#     269     covariance_[idx, idx]
#     270     - np.dot(covariance_[indices != idx, idx], coefs)
#     271 )
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_ufunc_config.py:435, in errstate.__exit__(self, *exc_info)
#     434 def __exit__(self, *exc_info):
# --> 435     seterr(**self.oldstate)
#     436     if self.call is not _Unspecified:
#     437         seterrcall(self.oldcall)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_ufunc_config.py:110, in seterr(all, divide, over, under, invalid)
#      34 """
#      35 Set how floating-point errors are handled.
#      36
#    (...)
#     106
#     107 """
#     109 pyvals = umath.geterrobj()
# --> 110 old = geterr()
#     112 if divide is None:
#     113     divide = all or old['divide']
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_ufunc_config.py:174, in geterr()
#     172 val = (maskvalue >> SHIFT_OVERFLOW) & mask
#     173 res['over'] = _errdict_rev[val]
# --> 174 val = (maskvalue >> SHIFT_UNDERFLOW) & mask
#     175 res['under'] = _errdict_rev[val]
#     176 val = (maskvalue >> SHIFT_INVALID) & mask
#
# KeyboardInterrupt:

# %%
len(models)
# Out:
# 100

# %%
#compare to make sure they don't look the same 
# bootstrap_samples[0]

# %%
# bootstrap_samples[1]

# %%
#checks the number of unique values in the bootstrap sample 
bootstrap_samples[1].index.nunique()
# Out:
# 91

# %%
#different metrics to calc 
#gpe, clus_coeff 
#density nx.density(G)
#eigenvector centrality nx.eigenvector_centrality(G) seems like its not a single value 
#assostivity coeff nx.degree_assortativity_coefficient(G) 
#diameter nx.diameter(G) -  Gives the diameter of the largest connected component in the graph, representing the longest shortest path between any pair of nodes. gave error 
#radius nx.radius - computes the radius of the largest connected compmenet gave error 
#number connected components nx.number_connected_components(G)

# %%
#graphical lasso cv not converging 
#can adjust the tolerance, regularization parameter alphas, change solver method, increase max iterations, or random seed 
#example 
#model = GraphicalLassoCV(tol=1e-3)  # Increase tolerance level
#alphas = [0.1, 1.0, 10.0]  # Example list of alpha values to search
#model = GraphicalLassoCV(alphas=alphas)

#model = GraphicalLassoCV(solver='graph_lasso')  # Try a different solver
#model = GraphicalLassoCV(max_iter=500)  # Increase maximum iterations
#model = GraphicalLassoCV(random_state=42)  # Set a random seed
#graphical lasso -  WITHOUT BOOTSTRAP  
#converges with 500 iterations 
#estimates the precision matrix of the data (inverse cov mat which models the partial correlations between vars)
#uses lasso penalty, during training the model iteratively updates the estimated precision matrix using current hyperparamter values until it converges to a set of values that minimize the loss function 
# model = GraphicalLassoCV(cv=5,max_iter=500) #cv=5 specifies 5-fold cross validation strategy to optimize model hyperparameters 
# model.fit(progs_norm)
#have 1 rv per node (volumes), find out the optimization details, theorteically estimating corr mat of vars 


#have data, then unconnected random var,s est cov mat, and this estimation has penalty to force very small numbers to be 0 (force some sparsity) then interpret the inverse cov matrix as an adjacency matrix, and then visualize as a graph 
#makes sense to trat as random var, they are connecte din some sense if they are correlated 

#drop the very small nunvbwers, l1 sets very small things to 0, choses hyper parater by cross validation

# %%
#RuntimeWarning: invalid value encountered in subtract x = asanyarray(arr - arrmean) 
#check data for nan values 
nan_mask = progs_norm.isna()
nan_count = nan_mask.sum().sum()
print(nan_count)

#under the assumption the vars are gaussian and correlated oit is estimated cov matrix 
#plot histrogram (for one brain region)
#if you have random var that is sum of other random var, with finite variance, then CLT holds, if its the sum of many processed, then it's reasonably gaussian 


#for embeddings - sklearkn might have covariance betwen 2 random vars, use dot product of vectors instead of product
# Out:
# 0

# %%
#just for graph visualization, doesn't work for bootstrapped because there's more than one pop graph 
#node size based on connectivity visualization 
#assigns node labels based on the column id 
#this doesn't work because it's the bootstrap sample list 
# precision_matrix_p = model.precision_
# np.fill_diagonal(precision_matrix_p, 0) #removes self connections by replacing the diagnonal of matrix with 0 

# G_prog = nx.Graph(precision_matrix_p)
# #create a dictionary that maps old node labels to new node labels
# node_labels = {i: label for i, label in enumerate(progs_norm.columns)}

# #relabel the nodes in the graph using the dictionary
# G_prog = nx.relabel_nodes(G_prog, node_labels)

# # Assuming you already have precision_matrix_np and G_n_prog as in your code
# # Calculate the node degrees (connectivity strength)
# node_degrees = dict(G_prog.degree())

# # Scale the node sizes based on node degrees
# node_sizes = [20 * node_degrees[node] for node in G_prog.nodes()]

# # Create a colormap for node colors based on node degrees
# node_colors = list(node_degrees.values())

# # Draw the graph with node sizes and colors
# pos = nx.random_layout(G_prog)
# nx.draw(
#     G_prog,
#     pos,
#     with_labels=True,
#     font_size=7,
#     style="dotted",
#     node_color=node_colors,
#     cmap=plt.cm.Reds,
#     node_size=node_sizes,
#     alpha=0.8,
#     width=0.3,
# )

# plt.title("Progressive MCI Population Graphical Model NACC", fontsize=22)
# plt.show()

#the random layout changes, to have the same one run the layout finctiopn first, choose what I want and then try it later 
#circular one might be good or spectral (bc it uses info on the degree of each node aware of hubs)
#since these are random seed rnadom generator to generate same layout 
#generate positions once and then pass same poisition dictioary 
#network x is generating citionary of 2d positins to draw function 
#draw in circle (then spot patterns that way)

# %%
#calc metrics 
# terating through each bootsrap sample model, calculating the graph metrics, and then storing the metrics for eahc model in a dataframe 
metrics_data = []
#to get variance, 

#keep track of index with enumerate 
for model_num, model in enumerate(models,start=1):
    precision_matrix_p = model.precision_
    np.fill_diagonal(precision_matrix_p, 0) #removes self connections by replacing the diagnonal of matrix with 0 
    G_prog = nx.Graph(precision_matrix_p)
    node_labels = {i: label for i, label in enumerate(progs_norm.columns)}
    #relabel the nodes in the graph using the dictionary
    G_prog = nx.relabel_nodes(G_prog, node_labels)
    #now calculate the metrics and store them 
    gpe = nx.global_efficiency(G_prog) 
    clustering_coefficient = nx.average_clustering(G_prog)
    density = nx.density(G_prog)
    # eigen_cen = nx.eigenvector_centrality(G_prog)
    ass_coeff = nx.degree_assortativity_coefficient(G_prog)
    # diameter = nx.diameter(G_prog)
    # radius = nx.radius(G_prog)


    #create dictionary for current models data 
# 49         50  0.447146    0.317940  0.089813   0.116458
# 50         51  0.477394    0.335249  0.106739   0.231439
# 51         52  0.455452    0.333339  0.102401   0.267929
# 52         53  0.460905    0.319485  0.097958   0.140347
# 53         54  0.486269    0.295878  0.107268   0.132344
# 54         55  0.458256    0.331662  0.101238   0.153094
# 55         56  0.473755    0.306598  0.100074   0.134591
# 56         57  0.479788    0.367476  0.107691   0.193758
# 57         58  0.468911    0.321401  0.102190   0.168473
# 58         59  0.473582    0.331646  0.103353   0.205101
# 59         60  0.472890    0.302899  0.099016   0.205796
# 60         61  0.442951    0.368325  0.100709   0.078254
# 61         62  0.484841    0.319299  0.106315   0.206629
# 62         63  0.467462    0.323259  0.097218   0.199145
# 63         64  0.366053    0.351361  0.081561   0.200595
# 64         65  0.468530    0.322508  0.101238   0.127898
# 65         66  0.467293    0.317742  0.101767   0.174236
# 66         67  0.462754    0.322572  0.099334   0.174132
# 67         68  0.475801    0.315624  0.102507   0.209802
# 68         69  0.467443    0.327834  0.105469   0.152393
# 69         70  0.480676    0.340820  0.104729   0.162150
# 70         71  0.487704    0.348338  0.110864   0.164672
# 71         72  0.459419    0.332857  0.105575   0.110777
# 72         73  0.471938    0.324145  0.106104   0.221051
# 73         74  0.467296    0.313714  0.100180   0.107489
# 74         75  0.462756    0.328487  0.102401   0.160930
# 75         76  0.480983    0.330218  0.105787   0.202620
# 76         77  0.472922    0.300853  0.105998   0.162231
# 77         78  0.446437    0.318282  0.093515   0.104530
# 78         79  0.467820    0.331663  0.103882   0.159947
# 79         80  0.453623    0.323004  0.100497   0.106682
# 80         81  0.473776    0.337793  0.103565   0.152023
# 81         82  0.468842    0.308233  0.094891   0.152203
# 82         83  0.466383    0.331176  0.103988   0.192328
# 83         84  0.467598    0.320885  0.100603   0.153514
# 84         85  0.455367    0.348315  0.105363   0.025319
# 85         86  0.469738    0.331092  0.104940   0.201377
# 86         87  0.483187    0.318604  0.105681   0.203972
# 87         88  0.451479    0.376473  0.110441   0.070273
# 88         89  0.372038    0.374124  0.081773   0.117062
# 89         90  0.477244    0.358936  0.112451   0.214284
# 90         91  0.471729    0.343870  0.097112   0.081604
# 91         92  0.466214    0.352048  0.097535   0.183688
# 92         93  0.441631    0.313026  0.095314   0.278143
# 93         94  0.474119    0.339378  0.110335   0.181170
# 94         95  0.466822    0.333342  0.098699   0.151811
# 95         96  0.478753    0.336178  0.106527   0.214802
# 96         97  0.460096    0.310613  0.102719   0.207000
# 97         98  0.469920    0.316316  0.097535   0.163925
# 98         99  0.455832    0.339225  0.103459   0.188623
# 99        100  0.422544    0.368886  0.100815   0.126943

# %%
#print(metrics_data)
#calc variance for each metric (which is col for each) like for mean 
#plot the variance for each metric/col across diff num samples (training curve)
# sklearn has training curve display 
# do it on estimator (graph lasso cv and training set) but do it on pop_ggm_code without bootstrap (good to have on poster)
# on bootstrapped data SSE ()

# %%
#heatmap of precision matrix (precision matrix is the inverse of the covariance matrix)

# Assuming models is your list of models
model_num = 0  # Change this to get the precision matrix of other models
precision_matrix = models[model_num].precision_

# Set the diagonal to zero if desired
np.fill_diagonal(precision_matrix, 0)

# Create a heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(precision_matrix, cmap='coolwarm', annot=False, vmin=-1, vmax=.25)  # assuming values range from -1 to 1
plt.title(f'Precision Matrix of Model {model_num + 1}')
plt.show()
print(np.min(precision_matrix), np.max(precision_matrix))

#stronger parital correlation is red but what if
# Out:
# -0.844785262641784 0.030191171960101192

# %%
#run bootstrap for stable df 
np.random.seed(3)
stab_num_bootstrap_samples = 100
stab_bootstrap_precision_matrices = []
stab_bootstrap_samples = []
for x in range(stab_num_bootstrap_samples):
    #sample with replacement, randomstate =1 for reporoducibility 
    stab_bootstrap_sample = stable_norm.sample(n=len(stable_norm),replace=True)
    #append resamples df to a list 
    stab_bootstrap_samples.append(stab_bootstrap_sample)

# %%
# #bootstrap and plot stable 
# #bootstrap for stable adni 
# stab_num_bootstrap_samples = 5 
# stab_bootstrap_precision_matrices = []
# stab_bootstrap_samples = []
# for x in range(stab_num_bootstrap_samples):
#     #sample with replacement, randomstate =1 for reporoducibility 
#     stab_bootstrap_sample = stable_norm.sample(n=len(stable_norm),replace=True, random_state=1)
#     #append resamples df to a list 
#     stab_bootstrap_samples.append(stab_bootstrap_sample)

# %%
#run graphical model on bootstrapped sample 
stab_models = []
for stab_bootstrap_sample in tqdm(stab_bootstrap_samples):
    #if I give it alphas [1,10] it looks like it drops almost all of the connections 
    
    stab_model = GraphicalLassoCV(cv=2,max_iter=50,tol=1e-3)
    stab_model.fit(stab_bootstrap_sample)
    stab_models.append(stab_model)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   1%|          | 1/100 [00:04<08:08,  4.93s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   2%|▏         | 2/100 [00:10<08:34,  5.25s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   3%|▎         | 3/100 [00:14<08:00,  4.95s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   4%|▍         | 4/100 [00:19<07:33,  4.72s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   5%|▌         | 5/100 [00:24<07:39,  4.84s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   6%|▌         | 6/100 [00:29<07:37,  4.87s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   7%|▋         | 7/100 [00:34<07:37,  4.92s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   8%|▊         | 8/100 [00:39<07:45,  5.06s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   9%|▉         | 9/100 [00:44<07:34,  4.99s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  10%|█         | 10/100 [00:49<07:35,  5.07s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  11%|█         | 11/100 [00:54<07:21,  4.96s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  12%|█▏        | 12/100 [00:59<07:21,  5.01s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  13%|█▎        | 13/100 [01:05<07:35,  5.24s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  14%|█▍        | 14/100 [01:10<07:34,  5.28s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  15%|█▌        | 15/100 [01:16<07:28,  5.28s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  16%|█▌        | 16/100 [01:20<07:12,  5.15s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  17%|█▋        | 17/100 [01:26<07:06,  5.14s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:297: ConvergenceWarning: graphical_lasso: did not converge after 50 iteration: dual gap: -1.422e-03
#   warnings.warn(
#  18%|█▊        | 18/100 [01:31<07:14,  5.30s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  19%|█▉        | 19/100 [01:37<07:10,  5.32s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  20%|██        | 20/100 [01:42<07:12,  5.41s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  21%|██        | 21/100 [01:47<07:03,  5.36s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  22%|██▏       | 22/100 [01:53<06:53,  5.31s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  23%|██▎       | 23/100 [01:57<06:36,  5.15s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  24%|██▍       | 24/100 [02:02<06:29,  5.12s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py
/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  78%|███████▊  | 78/100 [06:38<01:49,  4.97s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  79%|███████▉  | 79/100 [06:44<01:47,  5.10s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  80%|████████  | 80/100 [06:49<01:43,  5.19s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  81%|████████  | 81/100 [06:54<01:38,  5.18s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  82%|████████▏ | 82/100 [07:00<01:34,  5.27s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  83%|████████▎ | 83/100 [07:05<01:31,  5.36s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  84%|████████▍ | 84/100 [07:10<01:24,  5.30s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  85%|████████▌ | 85/100 [07:15<01:18,  5.25s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  86%|████████▌ | 86/100 [07:20<01:10,  5.05s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  87%|████████▋ | 87/100 [07:25<01:06,  5.14s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  88%|████████▊ | 88/100 [07:31<01:03,  5.28s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  89%|████████▉ | 89/100 [07:36<00:57,  5.23s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:297: ConvergenceWarning: graphical_lasso: did not converge after 50 iteration: dual gap: -1.255e-03
#   warnings.warn(
#  90%|█████████ | 90/100 [07:42<00:54,  5.47s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  91%|█████████ | 91/100 [07:47<00:48,  5.38s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  92%|█████████▏| 92/100 [07:53<00:44,  5.51s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  93%|█████████▎| 93/100 [07:58<00:37,  5.37s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  94%|█████████▍| 94/100 [08:03<00:31,  5.32s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  95%|█████████▌| 95/100 [08:09<00:27,  5.43s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  96%|█████████▌| 96/100 [08:14<00:21,  5.41s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  97%|█████████▋| 97/100 [08:19<00:15,  5.26s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  98%|█████████▊| 98/100 [08:24<00:10,  5.22s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  99%|█████████▉| 99/100 [08:29<00:05,  5.12s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# 100%|██████████| 100/100 [08:35<00:00,  5.15s/it]

# %%
# stab_models.to_csv('/data2/MRI_PET_DATA/graph/csvs/bootstrap_models_and_metrics/full_bootstrap_models_stab.csv')
#this doesn't work because the bootstrap is a list

# %%
#check that the bootstrap values are unique 
stab_bootstrap_samples[1].index.nunique()
# Out:
# 235

# %%
# #plot graph just for viualization doesn't work if there are more than one 
# #this doesn't work because the fraph is 
# precision_matrix_s = stab_model.precision_
# np.fill_diagonal(precision_matrix_s, 0) #removes self connections by replacing the diagnonal of matrix with 0 

# G_stab = nx.Graph(precision_matrix_s)
# #create a dictionary that maps old node labels to new node labels
# node_labels = {i: label for i, label in enumerate(stable_norm.columns)}

# #relabel the nodes in the graph using the dictionary
# G_stab = nx.relabel_nodes(G_stab, node_labels)

# #visualize the relabeled graph
# pos = nx.random_layout(G_stab)
# nx.draw(G_stab, pos, with_labels=True, font_size=7, style="dotted",
#         node_color=range(len(G_stab)), cmap=plt.cm.Blues,
#         node_size=150*len(G_stab)/154, alpha=.8, width=.3)
# plt.title("Stable MCI Population Graphical Model ADNI", fontsize=22)
# plt.show()

# %%
# Assuming stable_norm and stab_models are already defined somewhere

stab_metrics_data = []

for stab_model_num, stab_model in enumerate(stab_models):
    precision_matrix_stab = stab_model.precision_
    np.fill_diagonal(precision_matrix_stab, 0)  # removes self connections by replacing the diagonal of matrix with 0
    G_stab = nx.Graph(precision_matrix_stab)
    # create a dictionary that maps old node labels to new node labels
    stab_node_labels = {i: label for i, label in enumerate(stable_norm.columns)}
    # relabel the nodes in the graph using the dictionary
    G_stab = nx.relabel_nodes(G_stab, stab_node_labels)
    # now calculate the metrics and store them
    stab_gpe = nx.global_efficiency(G_stab)
    stab_clustering_coefficient = nx.average_clustering(G_stab)

    # Assuming you want to store metrics for stab (stability) models,
    # not prog (progression) models as shown in the second snippet
    stab_density = nx.density(G_stab)
    stab_ass_coeff = nx.degree_assortativity_coefficient(G_stab)

    # metrics dictionary
    stab_metrics_dic = {'model_num': stab_model_num,
                        'gpe': stab_gpe,
                        'clus_coeff': stab_clustering_coefficient,
                        'density': stab_density,
                        'ass_coeff': stab_ass_coeff
                        }

    stab_metrics_data.append(stab_metrics_dic)

stab_metrics_data = pd.DataFrame(stab_metrics_data)
stab_metrics_data.to_csv('/data2/MRI_PET_DATA/graph/csvs/bootstrap_models_and_metrics/50_bootstrap_models_stab_metrics.csv')
print(stab_metrics_data)
# Out:
#     model_num       gpe  clus_coeff   density  ass_coeff
# 0           0  0.467661    0.409867  0.117740   0.230581
# 1           1  0.462437    0.432026  0.119539   0.185521
# 2           2  0.479908    0.392549  0.115836   0.189562
# 3           3  0.478471    0.390108  0.117529   0.213140
# 4           4  0.472795    0.388837  0.119221   0.251775
# 5           5  0.479869    0.410742  0.118587   0.188697
# 6           6  0.475600    0.376136  0.120808   0.267426
# 7           7  0.468026    0.396291  0.117211   0.224252
# 8           8  0.485735    0.372549  0.120702   0.176863
# 9           9  0.481422    0.406232  0.119539   0.163524
# 10         10  0.473791    0.393821  0.119645   0.225369
# 11         11  0.483372    0.376420  0.121126   0.220724
# 12         12  0.465711    0.421243  0.123453   0.186581
# 13         13  0.470424    0.375687  0.118375   0.274405
# 14         14  0.475870    0.392994  0.121549   0.232506
# 15         15  0.485290    0.406077  0.117211   0.219178
# 16         16  0.483007    0.395902  0.120808   0.162417
# 17         17  0.473541    0.374122  0.119539   0.212361
# 18         18  0.469549    0.397291  0.116154   0.224541
# 19         19  0.479275    0.393251  0.121020   0.182935
# 20         20  0.478492    0.377282  0.116259   0.220255
# 21         21  0.468151    0.401296  0.115413   0.194205
# 22         22  0.467241    0.399566  0.116154   0.204173
# 23         23  0.470173    0.396134  0.117106   0.184475
# 24         24  0.476267    0.392540  0.122924   0.234240
# 25         25  0.482982    0.401098  0.128954   0.213321
# 26         26  0.470590    0.404035  0.117317   0.141108
# 27         27  0.473935    0.384128  0.116894   0.212968
# 28         28  0.477698    0.385159  0.117529   0.247571
# 29         29  0.487920    0.387337  0.119221   0.222494
# 30         30  0.472949    0.384217  0.117000   0.202591
# 31         31  0.478264    0.392808  0.119010   0.210714
# 32         32  0.474296    0.403775  0.119116   0.188849
# 33         33  0.472471    0.389116  0.118058   0.230017
# 34         34  0.485469    0.395875  0.117317   0.177562
# 35         35  0.466369    0.409642  0.117952   0.247180
# 36         36  0.475981    0.395335  0.116471   0.199911
# 37         37  0.482513    0.383364  0.118058   0.213248
# 38         38  0.476589    0.366442  0.117211   0.200683
# 39         39  0.484899    0.380181  0.123136   0.132949
# 40         40  0.475854    0.397386  0.122924   0.248434
# 41         41  0.478277    0.397553  0.124828   0.240003
# Initialize lists or a DataFrame to store your results
cols = []
p_values = []
t_stats = []

for col in metrics_data.columns:  
    if col != 'model_num':
    # Get data for this brain region from both datasets
        progs_data = metrics_data[col]
        stab_data = stab_metrics_data[col]
        
        # Perform t-test
        t_stat, p_val = stats.ttest_ind(progs_data, stab_data, equal_var=False)  # Assuming variance might not be equal
        
        # Store results
        cols.append(col)
        t_stats.append(t_stat)
        p_values.append(p_val)

    # Combine results into a DataFrame for easy viewing and further analysis
    results_df = pd.DataFrame({
        'Brain Region': cols,
        'T-Statistic': t_stats,
        'P-Value': p_values
})

# Adding the Significant column based on the P-Value
results_df['Significant'] = results_df['P-Value'] < 0.05

# Display or save the results
print(results_df)
# Optionally save to a CSV file
# results_df.to_csv('t_test_results.csv', index=False)

#the resulting negative t stats mean the progs have lower volume than the stab which is good 
results_df.to_csv('/data2/MRI_PET_DATA/graph/csvs/bootstrap_models_and_metrics/50_bootstrap_models_ttest.csv')
# Out:
#   Brain Region  T-Statistic       P-Value  Significant
# 0          gpe    -6.349198  3.268807e-09         True
# 1   clus_coeff   -22.606128  9.647343e-57         True
# 2      density   -27.292662  1.028930e-63         True
# 3    ass_coeff    -5.030910  1.270020e-06         True

# %% [markdown]
# Interpreting t test results:
# 1. GPE was lower for progressive MCI
# -Global path effiency is a measure of the effiency of information exchange across the network, a lower efficency indicates that the graph network is not effiently structured and that information has to travel more indirectly between nodes
#
# 2. clustering coefficent was lower for progressive MCI
# - Clustering coefficient is extent to which nodes in a graph are organized into clusters.
# - Specifically, the average clustering coefficient calculates the mean of local clustering coefficients of all the vertices in the network. A higher clustering coefficient indicates a higher degree of clustering in the network.
#
# 3. Graph density was lower for progressive MCI
# - density is a measure of how closely knit the network is (low density value is a more sparse network)
#
# 4. Assortivity coefficient was lower for progressive MCI
# - correlation coefficient for degrees of connected nodes
# - lower assortativity is indicates that nodes with a high degree tend to connect with nodes of low degree (dissasortive mixing)

# %%
#now try for nacc 
comb_gmv_nacc = pd.read_csv("/data2/MRI_PET_DATA/graph/csvs/graph_gmv_volumes/mike_gmv_nacc_combo.csv")
comb_gmv_nacc = comb_gmv_nacc.drop(['Unnamed: 0'], axis=1)
print(comb_gmv_nacc.dtypes)
# Out:
# RID                   object
# TIV                  float64
# vol_l3thVen          float64
# vol_r3thVen          float64
# vol_l4thVen          float64
# vol_r4thVen          float64
# vol_lAcc             float64
# vol_rAcc             float64
# vol_lAmy             float64
# vol_rAmy             float64
# vol_lBst             float64
# vol_rBst             float64
# vol_lCau             float64
# vol_rCau             float64
# vol_lExtCbe          float64
# vol_rExtCbe          float64
# vol_lCbeWM           float64
# vol_rCbeWM           float64
# vol_lCbrWM           float64
# vol_rCbrWM           float64
# vol_lCSF             float64
# vol_rCSF             float64
# vol_lHip             float64
# vol_rHip             float64
# vol_lInfLatVen       float64
# vol_rInfLatVen       float64
# vol_lLatVen          float64
# vol_rLatVen          float64
# vol_lPal             float64
# vol_rPal             float64
# vol_lPut             float64
# vol_rPut             float64
# vol_lThaPro          float64
# vol_rThaPro          float64
# vol_lVenVen          float64
# vol_rVenVen          float64
# vol_lOC              float64
# vol_rOC              float64
# vol_lCbeLoCbe1-5     float64
# vol_rCbeLoCbe1-5     float64
# vol_lCbeLoCbe6-7     float64
# vol_rCbeLoCbe6-7     float64
# vol_lCbeLoCbe8-10    float64
# vol_rCbeLoCbe8-10    float64
# vol_lBasCbr+FobBr    float64
# vol_rBasCbr+FobBr    float64
# vol_lAntCinGy        float64
# vol_rAntCinGy        float64
# vol_lAntIns          float64
# vol_rAntIns          float64
# vol_lAntOrbGy        float64
# vol_rAntOrbGy        float64
# vol_lAngGy           float64
# vol_rAngGy           float64
# vol_lCal+Cbr         float64
# vol_rCal+Cbr         float64
# vol_lCenOpe          float64
# vol_rCenOpe          float64
# vol_lCun             float64
# vol_rCun             float64
# vol_lEnt             float64
# vol_rEnt             float64
# vol_lFroOpe          float64
# vol_rFroOpe          float64
# vol_lFroPo           float64
# vol_rFroPo           float64
# vol_lFusGy           float64
# vol_rFusGy           float64
# vol_lRecGy           float64
# vol_rRecGy           float64
# vol_lInfOccGy        float64
# vol_rInfOccGy        float64
# vol_lInfTemGy        float64
# vol_rInfTemGy        float64
# vol_lLinGy           float64
# vol_rLinGy           float64
# vol_lLatOrbGy        float64
# vol_rLatOrbGy        float64
# vol_lMidCinGy        float64
# vol_rMidCinGy        float64
# vol_lMedFroCbr       float64
# vol_rMedFroCbr       float64
# vol_lMidFroGy        float64
# vol_rMidFroGy        float64
# vol_lMidOccGy        float64
# vol_rMidOccGy        float64
# vol_lMedOrbGy        float64
# vol_rMedOrbGy        float64
# vol_lMedPoCGy        float64
# vol_rMedPoCGy        float64
# vol_lMedPrcGy        float64
# vol_rMedPrcGy        float64
# vol_lSupMedFroGy     float64
# vol_rSupMedFroGy     float64
# vol_lMidTemGy        float64
# vol_rMidTemGy        float64
# vol_lOccPo           float64
# vol_rOccPo           float64
# vol_lOccFusGy        float64
# vol_rOccFusGy        float64
# vol_lInfFroGy        float64
# vol_rInfFroGy        float64
# vol_lInfFroOrbGy     float64
# vol_rInfFroOrbGy     float64
# vol_lPosCinGy        float64
# vol_rPosCinGy        float64
# vol_lPCu             float64
# vol_rPCu             float64
# vol_lParHipGy        float64
# vol_rParHipGy        float64
# vol_lPosIns          float64
# vol_rPosIns          float64
# vol_lParOpe          float64
# vol_rParOpe          float64
# vol_lPoCGy           float64
# vol_rPoCGy           float64
# vol_lPosOrbGy        float64
# vol_rPosOrbGy        float64
# vol_lPla             float64
# vol_rPla             float64
# vol_lPrcGy           float64
# vol_rPrcGy           float64
# vol_lTem             float64
# vol_rTem             float64
# vol_lSCA             float64
# vol_rSCA             float64
# vol_lSupFroGy        float64
# vol_rSupFroGy        float64
# vol_lCbr+Mot         float64
# vol_rCbr+Mot         float64
# vol_lSupMarGy        float64
# vol_rSupMarGy        float64
# vol_lSupOccGy        float64
# vol_rSupOccGy        float64
# vol_lSupParLo        float64
# vol_rSupParLo        float64
# vol_lSupTemGy        float64
# vol_rSupTemGy        float64
# vol_lTemPo           float64
# vol_rTemPo           float64
# vol_lInfFroAngGy     float64
# vol_rInfFroAngGy     float64
# vol_lTemTraGy        float64
# vol_rTemTraGy        float64
# Dataset               object
# dtype: object

# %%
nacc_prog_rids = pd.read_csv("/data2/MRI_PET_DATA/graph/NACC/Morph/mri_atlas/morph/roi/NACC_progressors_vol.csv")
nacc_stab_rids = pd.read_csv("/data2/MRI_PET_DATA/graph/NACC/Morph/mri_atlas/morph/roi/NACC_stable_vol.csv")
# print(nacc_prog_rids)

# %%
nacc_prog_rids = nacc_prog_rids.drop(['Unnamed: 0'], axis=1) #drop col 
nacc_stab_rids = nacc_stab_rids.drop(['Unnamed: 0'],axis=1)
# print(nacc_stab_rids.dtypes)

# %%
print(nacc_stab_rids.dtypes)
# Out:
# RID           object
# PROGRESSES     int64
# 1              int64
# 2              int64
# 3              int64
# 4              int64
# 5              int64
# 6              int64
# 7              int64
# 8              int64
# 9              int64
# 10             int64
# 11             int64
# 12             int64
# 13             int64
# 14             int64
# 15             int64
# 16             int64
# 17             int64
# 18             int64
# 19             int64
# 20             int64
# 21             int64
# 22             int64
# 23             int64
# 24             int64
# 25             int64
# 26             int64
# 27             int64
# 28             int64
# 29             int64
# 30             int64
# 31             int64
# 32             int64
# 33             int64
# 34             int64
# 35             int64
# 36             int64
# 37             int64
# 38             int64
# 39             int64
# 40             int64
# 41             int64
# 42             int64
# 43             int64
# 44             int64
# 45             int64
# 46             int64
# 47             int64
# 48             int64
# 49             int64
# 50             int64
# 51             int64
# 52             int64
# 53             int64
# 54             int64
# 55             int64
# 56             int64
# 57             int64
# 58             int64
# 59             int64
# 60             int64
# 61             int64
# 62             int64
# 63             int64
# 64             int64
# 65             int64
# 66             int64
# 67             int64
# 68             int64
# 69             int64
# 70             int64
# 71             int64
# 72             int64
# 73             int64
# 74             int64
# 75             int64
# 76             int64
# 77             int64
# 78             int64
# 79             int64
# 80             int64
# 81             int64
# 82             int64
# 83             int64
# 84             int64
# 85             int64
# 86             int64
# 87             int64
# 88             int64
# 89             int64
# 90             int64
# 91             int64
# 92             int64
# 93             int64
# 94             int64
# 95             int64
# 96             int64
# 97             int64
# 98             int64
# 99             int64
# 100            int64
# 101            int64
# 102            int64
# 103            int64
# 104            int64
# 105            int64
# 106            int64
# 107            int64
# 108            int64
# 109            int64
# 110            int64
# 111            int64
# 112            int64
# 113            int64
# 114            int64
# 115            int64
# 116            int64
# 117            int64
# 118            int64
# 119            int64
# 120            int64
# 121            int64
# 122            int64
# 123            int64
# 124            int64
# 125            int64
# 126            int64
# 127            int64
# 128            int64
# 129            int64
# 130            int64
# 131            int64
# 132            int64
# 133            int64
# 134            int64
# 135            int64
# 136            int64
# 137            int64
# 138            int64
# 139            int64
# 140            int64
# 141            int64
# 142            int64
# dtype: object

# %%
#stratify them into prog and stable for nacc 
#double check these are correct 

#do this by cross referencing the stable dfs that I have before from other csv files 
#these are all object datatype so hopefull it will work without converting them to int 

# nacc_prog_rids['RID'] = nacc_prog_rids["RID"].astype('int64')
# nacc_stable_rids['RID']=nacc_stable_rids['RID'].astype('int64')
# comb_gmv_nacc['RID']=comb_gmv_nacc['RID'].astype('int64')

rid_comb_gmv = set(comb_gmv_nacc["RID"])
rid_nacc_prog = set(nacc_prog_rids['RID'])
rid_nacc_stab = set(nacc_stab_rids['RID'])


nacc_gmv_prog = pd.DataFrame()
nacc_gmv_stab = pd.DataFrame()


#itterows allows you to iterate through rows of a df (it returns an iterator which is a pairs of index and series (the data for that row) for each row)
for index, row in comb_gmv_nacc.iterrows():
    rid = row["RID"]

    if rid in rid_nacc_prog:
        #if that rid exists in adni_progs then append the row to adni_gmv
        nacc_gmv_prog = nacc_gmv_prog.append(row,ignore_index=True)
    else:  
        nacc_gmv_stab = nacc_gmv_stab.append(row,ignore_index=True) #if they arent prog they are stab 

print(nacc_gmv_stab)
# Out:
#             RID          TIV  vol_l3thVen  vol_r3thVen  vol_l4thVen  \
# 0    NACC000511  1555.177037     0.020264     0.013338     0.053174
# 1    NACC000531  1647.584787     0.067283     0.052440     0.099190
# 2    NACC003196  1362.881871     0.022565     0.022337     0.051906
# 3    NACC006009  1409.219319     0.051523     0.050538     0.053296
# 4    NACC006420  1323.345298     0.062451     0.058506     0.084043
# 5    NACC008987  1478.138655     0.021388     0.009847     0.054729
# 6    NACC013585  1683.455180     0.022341     0.019690     0.081929
# 7    NACC015412  1588.981310     0.038149     0.025824     0.093200
# 8    NACC015899  1385.628810     0.011388     0.010145     0.103969
# 9    NACC016502  1558.432298     0.040541     0.032090     0.095408
# 10   NACC018906  1440.794848     0.021863     0.025353     0.046620
# 11   NACC019767  1455.519980     0.042957     0.033051     0.057031
# 12   NACC022572  1420.393624     0.019902     0.010902     0.063051
# 13   NACC023061  1510.403713     0.076957     0.038325     0.066055
# 14   NACC025174  1508.563525     0.040118     0.019067     0.075137
# 15   NACC025694  1271.233690     0.030867     0.038859     0.054827
# 16   NACC026435  1268.421827     0.050635     0.051192     0.054883
# 17   NACC030231  1380.185732     0.026559     0.034100     0.092973
# 18   NACC031505  1504.682998     0.043079     0.030150     0.060505
# 19   NACC032047  1567.389910     0.037475     0.026431     0.069125
# 20   NACC034261  1281.801469     0.015952     0.011770     0.081256
# 21   NACC038911  1535.483863     0.040858     0.028054     0.055158
# 22   NACC041155  1481.774541     0.009957     0.006239     0.044820
# 23   NACC042407  1611.374325     0.015329     0.012224     0.045604
# 24   NACC044217  1386.819991     0.027913     0.035461     0.084786
# 25   NACC044372  1528.240571     0.027075     0.016337     0.070114
# 26   NACC045315  1499.724227     0.039627     0.040031     0.078545
# 27   NACC046497  1560.090180     0.056761     0.039325     0.086039
# 28   NACC048048  1395.794161     0.034859     0.044298     0.068773
# 29   NACC048697  1647.503276     0.034480     0.024013     0.050209
# 30   NACC049323  1336.587980     0.073004     0.071541     0.046867
# 31   NACC050158  1676.427785     0.060531     0.057251     0.095382
# 32   NACC050822  1493.077545     0.029506     0.020239     0.060224
# 33   NACC055934  1387.082686     0.020204     0.012643     0.076098
# 34   NACC060815  1443.863478     0.019161     0.015494     0.042937
# 146          2.912267       1.365976       0.946714    NACC
# 147          0.925577       0.412663       0.393620    NACC
# 148          2.523576       0.918981       1.056263    NACC
# 149          3.288620       1.409388       1.106161    NACC
# 150          2.973361       1.138533       1.043898    NACC
# 151          3.170306       0.964061       1.031793    NACC
# 152          3.715910       0.915753       1.024671    NACC
# 153          2.353116       0.880732       0.998585    NACC
# 154          2.928932       1.275247       1.104381    NACC
# 155          2.687545       0.832769       0.956988    NACC
# 156          3.701210       1.248702       1.064831    NACC
# 157          2.250722       0.793396       0.956541    NACC
# 158          3.992045       1.342977       0.949262    NACC
# 159          2.937643       1.080635       0.968659    NACC
# 160          2.855267       1.247227       1.072969    NACC
# 161          2.356494       0.626486       0.601400    NACC
# 162          2.527438       1.229238       1.023644    NACC
# 163          2.069747       0.754209       0.799403    NACC
# 164          2.300515       0.808501       0.620704    NACC
# 165          2.104592       1.115478       0.715388    NACC
# 166          2.847647       0.783075       0.730906    NACC
# 167          2.767011       1.271819       1.105482    NACC
# 168          2.326349       0.881827       0.882110    NACC
# 169          3.058395       1.054107       1.156125    NACC
# 170          2.538157       0.943765       0.908706    NACC
# 171          2.973278       1.361533       1.290965    NACC
# 172          2.739591       0.969932       0.941634    NACC
# 173          3.317014       1.195875       1.069295    NACC
# 174          2.467326       0.977804       0.783745    NACC
# 175          3.013633       1.241701       0.923082    NACC
# 176          2.178891       0.875002       0.871665    NACC
# 177          3.541688       1.036674       1.035572    NACC
# 178          2.285490       0.855165       0.769153    NACC
# 179          2.955447       1.172255       1.059796    NACC
# 180          1.832261       0.757994       0.630674    NACC
# 181          3.100878       1.232149       1.080373    NACC
# 182          0.981653       0.851209       0.783523    NACC
# 183          3.132997       0.923449       0.897252    NACC
# 184          2.345886       0.907620       0.800518    NACC
# 185          2.945133       0.842416       0.890510    NACC
# 186          2.753478       1.096282       1.093651    NACC
# 187          2.975581       0.939699       0.925868    NACC
# 188          2.477867       1.297792       0.820949    NACC
# 189          2.917176       0.852258       0.765243    NACC
# 190          3.058659       1.446904       1.367083    NACC
# 191          3.027169       1.143992       1.077741    NACC
# 192          2.766902       1.140306       0.886502    NACC
# 193          2.386869       1.019254       0.701066    NACC
# 194          2.976486       1.042369       1.085306    NACC
# 195          3.023608       1.089564       1.059182    NACC
# 196          2.565329       1.004082       0.791271    NACC
# 197          2.849976       0.922949       0.781471    NACC
# 198          2.604767       1.085959       0.871168    NACC
# 199          3.115620       1.531780       1.398439    NACC
# 200          3.205780       1.402631       0.970345    NACC
# 201          1.951734       0.774934       0.695386    NACC
# 202          3.079569       1.605702       1.549086    NACC
# 203          3.282899       1.318936       1.116461    NACC
# 204          2.184145       0.844600       0.780949    NACC
# 205          2.634114       1.057008       0.896741    NACC
# 206          2.761166       1.190151       1.077804    NACC
# 207          2.270752       1.213152       0.784703    NACC
# 208          2.837460       0.640358       0.926608    NACC
# 209          3.614187       1.598492       1.405080    NACC
# 210          2.275616       0.671888       0.840781    NACC
# 211          2.822627       0.865200       0.778271    NACC
# 212          2.925882       0.794290       0.751102    NACC
# 213          3.597988       0.980314       1.003062    NACC
# 214          2.497408       1.111475       1.128875    NACC
# 215          3.386491       1.138173       1.053160    NACC
# 216          2.894477       1.023531       0.911041    NACC
# 217          2.771871       1.074698       1.028973    NACC
# 218          2.385468       0.960325       0.781292    NACC
# 219          3.358002       0.778418       0.683778    NACC
# 220          2.726600       0.739595       0.650698    NACC
# 221          2.539134       0.908521       0.676940    NACC
# 222          2.495784       0.835788       0.901729    NACC
# 223          3.040102       0.986897       1.026553    NACC
# 224          3.052048       1.095984       0.912282    NACC
# 225          2.654250       1.065972       0.984107    NACC
# 226          2.307676       0.826832       0.871938    NACC
# 227          2.714290       0.955003       0.887716    NACC
# 228          2.556223       0.882766       0.974038    NACC
# 229          3.372475       1.569063       1.010224    NACC
# 230          2.857843       1.087173       0.885106    NACC
# 231          2.901533       1.365067       0.949753    NACC
# 232          2.549231       0.886839       0.781729    NACC
# 233          3.018610       1.013340       0.982591    NACC
# 234          2.359643       1.343239       1.218979    NACC
# 235          2.596322       1.444180       1.197427    NACC
# 236          1.650907       1.054433       1.191982    NACC
# 237          3.123106       1.304647       1.299094    NACC
# 238          2.392306       1.001141       0.818894    NACC
# 239          3.147816       1.348851       1.202420    NACC
# 240          2.645739       0.662427       0.557859    NACC
# 241          2.309521       0.953631       0.838968    NACC
# 242          2.875203       1.167664       0.891283    NACC
# 243          2.779180       0.800627       0.845953    NACC
# 244          2.711122       0.827682       0.934639    NACC
# 245          3.132471       1.312102       0.926741    NACC
# 246          3.489947       1.153703       0.995453    NACC
# 247          3.047106       1.161212       0.942514    NACC
# 248          2.208632       1.180072       0.893509    NACC
# 249          2.877855       1.235388       1.232188    NACC
# 250          2.776164       0.839004       0.665521    NACC
# 251          3.479392       1.536875       1.212675    NACC
# 252          2.305698       1.187926       0.746584    NACC
# 253          2.554886       1.131435       0.943792    NACC
# 254          2.205730       1.299565       0.977423    NACC
# 255          2.418460       0.833020       0.741695    NACC
# 256          3.913413       0.751017       0.810414    NACC
# 257          3.370851       1.269565       1.026765    NACC
# 258          2.718903       0.913981       1.007676    NACC
# 259          3.147200       1.076329       1.009439    NACC
# 260          2.756392       1.133502       0.926408    NACC
# 261          3.688678       1.406694       1.328643    NACC
# 262          2.553524       1.152800       1.006591    NACC
# 263          2.910855       1.638710       1.272267    NACC
# 264          3.202608       1.417761       1.342576    NACC
# 265          2.325224       0.778879       0.652226    NACC
# 266          2.831443       1.108682       0.866604    NACC
# 267          2.957157       1.192749       0.963729    NACC
# 268          2.550151       0.960552       0.673099    NACC
# 269          2.248482       1.118804       0.798373    NACC
# 270          3.232663       1.263416       1.062616    NACC
# 271          2.153902       0.941296       0.743609    NACC
# 272          2.573224       1.158686       0.898557    NACC
# 273          2.367663       1.033455       0.998322    NACC
# 274          2.976770       1.077458       1.001629    NACC
# 275          2.687476       0.787177       0.820263    NACC
# 276          2.736236       0.763825       0.772325    NACC
# 277          3.121480       0.767703       0.927764    NACC
# 278          2.665773       0.886620       0.759212    NACC
# 279          3.848490       1.692710       1.158094    NACC
# 280          2.334788       0.717780       0.678365    NACC
# 281          3.412825       1.308801       1.117567    NACC
# 282          2.612176       1.235294       1.006929    NACC
# 283          1.916365       0.859876       0.829512    NACC
# 284          2.476450       0.741876       0.882036    NACC
# 285          2.940333       1.030655       0.977067    NACC
# 286          2.662259       1.071827       0.796125    NACC
# 287          3.375047       1.284573       0.942282    NACC
# 288          2.498463       0.939933       0.925165    NACC
# 289          2.654961       0.974263       0.917192    NACC
# 290          3.294180       1.201349       0.994376    NACC
# 291          2.326370       0.956378       0.924708    NACC
# 292          2.553523       1.020450       0.866942    NACC
# 293          2.677704       1.394900       0.974748    NACC
# 294          2.500400       0.956757       0.933004    NACC
# 295          0.507341       1.279639       0.177412    NACC
# 296          2.027075       1.041741       0.798259    NACC
# 297          2.764055       1.433251       1.218326    NACC
# 298          2.540302       0.987306       0.690275    NACC
# 299          2.931031       1.000980       0.838455    NACC
# 300          3.626762       1.568451       1.408662    NACC
# 301          2.375920       0.996977       0.752952    NACC
# 302          2.976788       1.113388       1.082455    NACC
# 303          2.779631       1.035655       0.997643    NACC
# 304          3.252945       1.143898       1.000467    NACC
# 305          2.866098       1.142718       0.934745    NACC
# 306          3.353569       1.219776       1.054573    NACC
# 307          2.554427       1.160408       1.003710    NACC
# 308          1.827597       0.900375       0.543067    NACC
# 309          2.848024       1.168471       0.878114    NACC
# 310          2.893604       1.177673       1.198448    NACC
# 311          2.872851       1.335106       1.030326    NACC
# 312          2.692666       0.845879       0.713299    NACC
# 313          2.217093       1.134062       0.855864    NACC
# 314          2.863616       1.117463       0.984886    NACC
# 315          2.270328       1.261688       1.108868    NACC
# 316          2.834124       0.850723       0.860460    NACC
# 317          3.781817       0.924146       0.778602    NACC
# 318          1.998566       0.720846       0.844885    NACC
# 319          3.194761       1.309694       1.033961    NACC
# 320          2.857114       0.942800       1.017055    NACC
# 321          2.475047       0.948678       0.902710    NACC
# 322          2.706089       0.594594       0.617339    NACC
# 323          3.554392       1.503463       1.465827    NACC
# 324          3.991349       1.534055       1.089106    NACC
# 325          2.696132       0.761031       0.829730    NACC
# 326          3.090648       1.075262       0.705261    NACC
# 327          2.611534       0.776092       0.532852    NACC
# 328          3.082585       1.409488       1.315624    NACC
# 329          2.789596       1.352894       1.193737    NACC
# 330          3.075353       1.218639       1.003114    NACC
# 331          3.534798       1.639047       1.416734    NACC
# 332          2.401008       1.078110       0.842851    NACC
# 333          2.470369       0.985935       0.743184    NACC
# 334          1.762275       0.733768       0.657942    NACC
# 335          3.753024       1.413682       1.152365    NACC
# 336          3.164166       0.889869       0.790527    NACC
# 337          2.511243       1.070707       1.051437    NACC
# 338          3.459816       1.174941       1.162584    NACC
# 339          3.158996       1.317271       1.059941    NACC
# 340          3.089263       0.788467       0.757651    NACC
# 341          2.860541       1.135875       1.145706    NACC
# 342          2.323031       0.761255       0.680608    NACC
# 343          2.504571       0.955074       0.904901    NACC
# 344          3.494569       0.921926       0.863557    NACC
# 345          2.829420       0.885408       0.851208    NACC
# 346          1.459054       0.761425       0.578613    NACC
# 347          2.605122       1.095424       1.003314    NACC
# 348          2.620435       1.155824       0.724800    NACC
# 349          2.597329       0.794055       0.881255    NACC
# 350          2.741605       0.860708       0.646378    NACC
# 351          3.032294       1.031656       0.801472    NACC
# 352          3.634537       1.015376       1.127620    NACC
# 353          3.166509       1.186069       1.217380    NACC
# 354          3.148401       1.099240       0.860938    NACC
# 355          2.815600       0.960337       0.815502    NACC
# 356          2.932826       1.081673       0.974311    NACC
# 357          3.863620       1.967016       1.780424    NACC
# 358          2.494341       0.652867       0.671310    NACC
# 359          3.394852       0.915602       0.972591    NACC
# 360          2.926986       1.155714       0.917587    NACC
# 361          2.339651       1.157306       0.781678    NACC
# 362          2.949728       1.242548       1.175386    NACC
# 363          1.996145       0.775737       0.680098    NACC
# 364          1.955022       0.916959       0.987290    NACC
# 365          2.599202       0.883428       0.703512    NACC
# 366          2.456844       1.272371       0.770139    NACC
# 367          3.469941       1.186882       1.184604    NACC
# 368          2.643704       1.131567       1.258735    NACC
# 369          3.844706       1.314596       1.042439    NACC
# 370          2.811059       1.290504       1.266591    NACC
# 371          3.344090       1.374523       1.314409    NACC
# 372          2.938000       1.082192       0.918573    NACC
# 373          3.432259       1.347454       1.301555    NACC
# 374          2.036483       0.950527       0.152126    NACC
# 375          2.384543       1.207687       1.106443    NACC
# 376          2.652906       0.972965       0.884043    NACC
# 377          3.134019       0.914220       0.925985    NACC

# %%
#nacc_gmv_prog 
nacc_gmv_prog = nacc_gmv_prog.drop(['RID','TIV','Dataset'], axis=1)
nacc_gmv_stab = nacc_gmv_stab.drop(['RID','TIV','Dataset'], axis=1)

# %%
#drop regions with 0 volume 
nacc_gmv_prog = nacc_gmv_prog.drop(['vol_lInfLatVen','vol_rInfLatVen','vol_lOC','vol_rOC'], axis=1)
nacc_gmv_stab = nacc_gmv_stab.drop(['vol_lInfLatVen','vol_rInfLatVen','vol_lOC','vol_rOC'],axis=1)

# %%
#check nacc gmv prog for 0 values

# Assuming nacc_gmv_prog is your dataframe
zero_values = (nacc_gmv_prog == 0).sum().sum()

print(f'Total zero values in the DataFrame: {zero_values}')
# Out:
# Total zero values in the DataFrame: 0

# %%
# print(nacc_gmv_stab)

# %%
#I guess scale the data like from original code because it involves distance metric 
#have to do standard scalar normalization 
#it normalizes by column 
#sklearn standard scalar 
scaler = StandardScaler()
#fit to your data and apply the transformation to your data 
nacc_progs_norm = scaler.fit_transform(nacc_gmv_prog)
nacc_stable_norm = scaler.fit_transform(nacc_gmv_stab)
print(nacc_progs_norm.shape)
print(nacc_progs_norm)
# Out:
# (130, 138)
# [[ 0.80534502  0.80672542 -1.21281711 ... -1.56645865 -0.18369921
#    0.18699365]
#  [-1.0017424  -1.37379319 -0.98761321 ... -1.44887849 -1.0843805
#   -0.86821437]
#  [ 0.64304712  1.26303585  3.21863655 ...  0.21128954  0.63693679
#    0.67087137]
#  ...
#  [-0.34222146  0.20341642 -1.53052567 ... -0.72510253 -0.38928224
#   -0.68852892]
#  [ 0.58160352  0.84561378 -0.63813427 ...  0.60840074 -0.16031015
# 94          -1.225229      -1.207160      -1.163229
# 95           0.931360       1.711532       1.142461
# 96           1.513763      -0.550464      -0.236762
# 97          -1.238558      -1.296179      -0.606197
# 98           0.492373      -0.263241       0.618186
# 99          -0.392818      -0.297314       0.770201
# 100          0.724402      -0.218838      -1.116518
# 101          0.587190       0.653325      -0.283200
# 102          0.144034       0.670562       1.260660
# 103          0.490461       1.254789       1.414663
# 104         -0.281318       0.695135       0.129625
# 105         -2.427530       0.096485       1.511295
# 106          0.772655       1.823383       1.696126
# 107          0.430303       0.093844      -0.011184
# 108          0.206703       0.928353       1.558333
# 109         -0.246274      -0.162113       0.187405
# 110         -1.418116      -1.360575      -1.031760
# 111         -0.732920      -0.205138       0.191768
# 112          0.042265       0.445105      -0.148943
# 113         -1.251080      -1.809683      -1.139872
# 114          1.559809      -0.010518       0.515598
# 115          0.675306      -1.305873      -0.786540
# 116          0.896983       0.747554       1.817496
# 117          1.621758      -0.528744       0.876308
# 118          0.709611       2.204988       1.589591
# 119          0.837605       1.334964       0.412614
# 120         -1.634353      -0.506462      -0.501068
# 121         -0.070100      -0.831001      -0.307981
# 122         -1.569788      -0.876431      -0.218529
# 123         -1.032942      -0.884268      -0.111177
# 124         -1.468841      -0.697479       0.212445
# 125          1.988453       2.262910       1.338242
# 126         -0.010526      -0.364763      -0.386911
# 127         -0.120789      -1.215082      -1.078244
# 128          1.123904       1.396740       0.073428
# 129          0.146797      -0.693709      -0.051264
# 130          1.602719      -0.782238      -0.273771
# 131         -0.363584       1.358109       1.191202
# 132         -0.581779      -0.988988      -2.098485
# 133         -0.425663      -2.008648      -1.866572
# 134          0.220663      -0.216510      -1.773960
# 135          0.143919       0.233967       0.100788
# 136          0.417815       0.548784      -0.598517
# 137         -1.112299       0.823633      -0.459728
# 138          0.672896       0.713516       1.251156
# 139         -0.080000       0.134582      -0.061402
# 140         -0.329593      -0.640594      -0.982385
# 141          0.335821       0.603371       1.078322
# 142          0.332966       0.731059       1.050507
# 143          0.145614      -0.209079       0.243320
# 144          0.610645      -0.146125       0.045504
# 145         -0.978181      -1.943980      -1.084125
# 146         -1.891434      -1.074701      -0.863757
# 147         -0.851151       0.318321       0.593544
# 148          0.646821       1.368302       0.956075
# 149         -1.843821       1.363402      -0.114003
# 150          0.998309       0.019313      -0.683077
# 151         -0.759991      -1.799838      -1.387681
# 152         -1.438297      -0.179683       1.265258
# 153         -0.690132      -0.209388      -0.845885

# %%
print(nacc_progs_norm.isnull().sum().sum())  # Sum of NaN values
print(nacc_progs_norm.isin([np.inf, -np.inf]).sum().sum())  # Sum of Inf values
# Out:
# 0
# 0

# %%
#check nacc gmv prog for 0 values

# Assuming nacc_gmv_prog is your dataframe
zero_values = (nacc_progs_norm == 0).sum().sum()

print(f'Total zero values in the DataFrame: {zero_values}')
# Out:
# Total zero values in the DataFrame: 0

# %%
nan_mask = nacc_progs_norm.isna()
nan_count = nan_mask.sum().sum()
print(nan_count)
# Out:
# 0

# %%
assert not nacc_progs_norm.isnull().values.any(), "Initial DataFrame has NaN values"
assert not np.isinf(nacc_progs_norm).values.any(), "Initial DataFrame has Inf values"

# %%
#run bootstrapping (with replacement) before the graphical lasso cv () 
#random_state = None means random number generator is inistalized, produces different set of rnadom samples each time 
#setting random state to 1 so that its reproducable 

#set random generator outside loop 
#seed everytrhing once at begibning and dont touch it 
np.random.seed(1)


num_bootstrap_samples = 50
nacc_bootstrap_precision_matrices = []
nacc_bootstrap_samples = []
for x in range(num_bootstrap_samples):
    #sample with replacement, randomstate =1 for reporoducibility 
    nacc_bootstrap_sample = nacc_progs_norm.sample(n=len(nacc_progs_norm),replace=True)
    #append resamples df to a list 
    nacc_bootstrap_samples.append(nacc_bootstrap_sample)

# %%
print(nacc_bootstrap_sample.dtypes)
# Out:
# vol_l3thVen          float64
# vol_r3thVen          float64
# vol_l4thVen          float64
# vol_r4thVen          float64
# vol_lAcc             float64
# vol_rAcc             float64
# vol_lAmy             float64
# vol_rAmy             float64
# vol_lBst             float64
# vol_rBst             float64
# vol_lCau             float64
# vol_rCau             float64
# vol_lExtCbe          float64
# vol_rExtCbe          float64
# vol_lCbeWM           float64
# vol_rCbeWM           float64
# vol_lCbrWM           float64
# vol_rCbrWM           float64
# vol_lCSF             float64
# vol_rCSF             float64
# vol_lHip             float64
# vol_rHip             float64
# vol_lLatVen          float64
# vol_rLatVen          float64
# vol_lPal             float64
# vol_rPal             float64
# vol_lPut             float64
# vol_rPut             float64
# vol_lThaPro          float64
# vol_rThaPro          float64
# vol_lVenVen          float64
# vol_rVenVen          float64
# vol_lCbeLoCbe1-5     float64
# vol_rCbeLoCbe1-5     float64
# vol_lCbeLoCbe6-7     float64
# vol_rCbeLoCbe6-7     float64
# vol_lCbeLoCbe8-10    float64
# vol_rCbeLoCbe8-10    float64
# vol_lBasCbr+FobBr    float64
# vol_rBasCbr+FobBr    float64
# vol_lAntCinGy        float64
# vol_rAntCinGy        float64
# vol_lAntIns          float64
# vol_rAntIns          float64
# vol_lAntOrbGy        float64
# vol_rAntOrbGy        float64
# vol_lAngGy           float64
# vol_rAngGy           float64
# vol_lCal+Cbr         float64
# vol_rCal+Cbr         float64
# vol_lCenOpe          float64
# vol_rCenOpe          float64
# vol_lCun             float64
# vol_rCun             float64
# vol_lEnt             float64
# vol_rEnt             float64
# vol_lFroOpe          float64
# vol_rFroOpe          float64
# vol_lFroPo           float64
# vol_rFroPo           float64
# vol_lFusGy           float64
# vol_rFusGy           float64
# vol_lRecGy           float64
# vol_rRecGy           float64
# vol_lInfOccGy        float64
# vol_rInfOccGy        float64
# vol_lInfTemGy        float64
# vol_rInfTemGy        float64
# vol_lLinGy           float64
# vol_rLinGy           float64
# vol_lLatOrbGy        float64
# vol_rLatOrbGy        float64
# vol_lMidCinGy        float64
# vol_rMidCinGy        float64
# vol_lMedFroCbr       float64
# vol_rMedFroCbr       float64
# vol_lMidFroGy        float64
# vol_rMidFroGy        float64
# vol_lMidOccGy        float64
# vol_rMidOccGy        float64
# vol_lMedOrbGy        float64
# vol_rMedOrbGy        float64
# vol_lMedPoCGy        float64
# vol_rMedPoCGy        float64
# vol_lMedPrcGy        float64
# vol_rMedPrcGy        float64
# vol_lSupMedFroGy     float64
# vol_rSupMedFroGy     float64
# vol_lMidTemGy        float64
# vol_rMidTemGy        float64
# vol_lOccPo           float64
# vol_rOccPo           float64
# vol_lOccFusGy        float64
# vol_rOccFusGy        float64
# vol_lInfFroGy        float64
# vol_rInfFroGy        float64
# vol_lInfFroOrbGy     float64
# vol_rInfFroOrbGy     float64
# vol_lPosCinGy        float64
# vol_rPosCinGy        float64
# vol_lPCu             float64
# vol_rPCu             float64
# vol_lParHipGy        float64
# vol_rParHipGy        float64
# vol_lPosIns          float64
# vol_rPosIns          float64
# vol_lParOpe          float64
# vol_rParOpe          float64
# vol_lPoCGy           float64
# vol_rPoCGy           float64
# vol_lPosOrbGy        float64
# vol_rPosOrbGy        float64
# vol_lPla             float64
# vol_rPla             float64
# vol_lPrcGy           float64
# vol_rPrcGy           float64
# vol_lTem             float64
# vol_rTem             float64
# vol_lSCA             float64
# vol_rSCA             float64
# vol_lSupFroGy        float64
# vol_rSupFroGy        float64
# vol_lCbr+Mot         float64
# vol_rCbr+Mot         float64
# vol_lSupMarGy        float64
# vol_rSupMarGy        float64
# vol_lSupOccGy        float64
# vol_rSupOccGy        float64
# vol_lSupParLo        float64
# vol_rSupParLo        float64
# vol_lSupTemGy        float64
# vol_rSupTemGy        float64
# vol_lTemPo           float64
# vol_rTemPo           float64
# vol_lInfFroAngGy     float64
# vol_rInfFroAngGy     float64
# vol_lTemTraGy        float64
# vol_rTemTraGy        float64
# dtype: object

# %%
# Check that all dataframes have the same datatypes for each column
datatypes = nacc_bootstrap_samples[0].dtypes  # Get datatypes of the first dataframe
same_datatypes = all((df.dtypes == datatypes).all() for df in nacc_bootstrap_samples)

print(f'All dataframes have the same datatypes for each column: {same_datatypes}')
# Out:
# All dataframes have the same datatypes for each column: True

# %%
# Assuming nacc_bootstrap_samples is your list of DataFrames
for i, df in enumerate(nacc_bootstrap_samples):
    if df.isnull().values.any():
        print(f'NaN values found in DataFrame at index {i}')
    else:
        print(f'No NaN values found in DataFrame at index {i}')

# If you want to see the total count of NaN values across all DataFrames:
total_nan_count = sum(df.isnull().sum().sum() for df in nacc_bootstrap_samples)
print(f'Total NaN count across all DataFrames: {total_nan_count}')
# Out:
# No NaN values found in DataFrame at index 0
# No NaN values found in DataFrame at index 1
# No NaN values found in DataFrame at index 2
# No NaN values found in DataFrame at index 3
# No NaN values found in DataFrame at index 4
# No NaN values found in DataFrame at index 5
# No NaN values found in DataFrame at index 6
# No NaN values found in DataFrame at index 7
# No NaN values found in DataFrame at index 8
# No NaN values found in DataFrame at index 9
# No NaN values found in DataFrame at index 10
# No NaN values found in DataFrame at index 11
# No NaN values found in DataFrame at index 12
# No NaN values found in DataFrame at index 13
# No NaN values found in DataFrame at index 14
# No NaN values found in DataFrame at index 15
# No NaN values found in DataFrame at index 16
# No NaN values found in DataFrame at index 17
# No NaN values found in DataFrame at index 18
# No NaN values found in DataFrame at index 19
# No NaN values found in DataFrame at index 20
# No NaN values found in DataFrame at index 21
# No NaN values found in DataFrame at index 22
# No NaN values found in DataFrame at index 23
# No NaN values found in DataFrame at index 24
# No NaN values found in DataFrame at index 25
# No NaN values found in DataFrame at index 26
# No NaN values found in DataFrame at index 27
# No NaN values found in DataFrame at index 28
# No NaN values found in DataFrame at index 29
# No NaN values found in DataFrame at index 30
# No NaN values found in DataFrame at index 31
# No NaN values found in DataFrame at index 32
# No NaN values found in DataFrame at index 33
# No NaN values found in DataFrame at index 34
# No NaN values found in DataFrame at index 35
# No NaN values found in DataFrame at index 36
# No NaN values found in DataFrame at index 37
# No NaN values found in DataFrame at index 38
# No NaN values found in DataFrame at index 39
# No NaN values found in DataFrame at index 40
# No NaN values found in DataFrame at index 41
# No NaN values found in DataFrame at index 42
# No NaN values found in DataFrame at index 43
# No NaN values found in DataFrame at index 44
# No NaN values found in DataFrame at index 45
# No NaN values found in DataFrame at index 46
# No NaN values found in DataFrame at index 47
# No NaN values found in DataFrame at index 48
# No NaN values found in DataFrame at index 49
# Total NaN count across all DataFrames: 0

# %%
import pandas as pd
import numpy as np

# Assuming nacc_bootstrap_samples is your list of DataFrames
for i, df in enumerate(nacc_bootstrap_samples):
    if np.isinf(df).values.any():
        print(f'Infinite values found in DataFrame at index {i}')
    else:
        print(f'No infinite values found in DataFrame at index {i}')

# If you want to see the total count of infinite values across all DataFrames:
total_inf_count = sum(np.isinf(df).sum().sum() for df in nacc_bootstrap_samples)
print(f'Total infinite count across all DataFrames: {total_inf_count}')
# Out:
# No infinite values found in DataFrame at index 0
# No infinite values found in DataFrame at index 1
# No infinite values found in DataFrame at index 2
# No infinite values found in DataFrame at index 3
# No infinite values found in DataFrame at index 4
# No infinite values found in DataFrame at index 5
# No infinite values found in DataFrame at index 6
# No infinite values found in DataFrame at index 7
# No infinite values found in DataFrame at index 8
# No infinite values found in DataFrame at index 9
# No infinite values found in DataFrame at index 10
# No infinite values found in DataFrame at index 11
# No infinite values found in DataFrame at index 12
# No infinite values found in DataFrame at index 13
# No infinite values found in DataFrame at index 14
# No infinite values found in DataFrame at index 15
# No infinite values found in DataFrame at index 16
# No infinite values found in DataFrame at index 17
# No infinite values found in DataFrame at index 18
# No infinite values found in DataFrame at index 19
# No infinite values found in DataFrame at index 20
# No infinite values found in DataFrame at index 21
# No infinite values found in DataFrame at index 22
# No infinite values found in DataFrame at index 23
# No infinite values found in DataFrame at index 24
# No infinite values found in DataFrame at index 25
# No infinite values found in DataFrame at index 26
# No infinite values found in DataFrame at index 27
# No infinite values found in DataFrame at index 28
# No infinite values found in DataFrame at index 29
# No infinite values found in DataFrame at index 30
# No infinite values found in DataFrame at index 31
# No infinite values found in DataFrame at index 32
# No infinite values found in DataFrame at index 33
# No infinite values found in DataFrame at index 34
# No infinite values found in DataFrame at index 35
# No infinite values found in DataFrame at index 36
# No infinite values found in DataFrame at index 37
# No infinite values found in DataFrame at index 38
# No infinite values found in DataFrame at index 39
# No infinite values found in DataFrame at index 40
# No infinite values found in DataFrame at index 41
# No infinite values found in DataFrame at index 42
# No infinite values found in DataFrame at index 43
# No infinite values found in DataFrame at index 44
# No infinite values found in DataFrame at index 45
# No infinite values found in DataFrame at index 46
# No infinite values found in DataFrame at index 47
# No infinite values found in DataFrame at index 48
# No infinite values found in DataFrame at index 49
# Total infinite count across all DataFrames: 0

# %%
# for index, value in enumerate(nacc_bootstrap_samples):
#     if math.isnan(value):
#         print(f'NaN found at index {index}')

# %%
#run graphical model on bootstrapped sample 
#it worked changing the random seed so fingers crossed 
#setting random seed to 3 changed it so it wasn't generating sample with inf or nan values 
#setting random seed as 3 and 100 samples works 
nacc_models = []
for nacc_bootstrap_sample in tqdm(nacc_bootstrap_samples):
    nacc_model = GraphicalLassoCV(cv=2,max_iter=50, tol=1e-3)
    nacc_model.fit(nacc_bootstrap_sample)
    nacc_models.append(nacc_model) 

#error that it must not contain infs or nans
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   2%|▏         | 1/50 [00:05<04:19,  5.30s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   4%|▍         | 2/50 [00:09<03:53,  4.86s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   6%|▌         | 3/50 [00:15<03:58,  5.08s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   8%|▊         | 4/50 [00:19<03:47,  4.95s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  10%|█         | 5/50 [00:25<03:46,  5.04s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  12%|█▏        | 6/50 [00:30<03:41,  5.03s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  14%|█▍        | 7/50 [00:35<03:39,  5.10s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  16%|█▌        | 8/50 [00:40<03:35,  5.12s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  18%|█▊        | 9/50 [00:45<03:29,  5.11s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  20%|██        | 10/50 [00:50<03:25,  5.14s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  22%|██▏       | 11/50 [00:55<03:19,  5.12s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  24%|██▍       | 12/50 [01:01<03:18,  5.22s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  26%|██▌       | 13/50 [01:06<03:13,  5.24s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  28%|██▊       | 14/50 [01:12<03:14,  5.40s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  30%|███       | 15/50 [01:17<03:03,  5.24s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  32%|███▏      | 16/50 [01:22<03:00,  5.31s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  34%|███▍      | 17/50 [01:27<02:46,  5.06s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  36%|███▌      | 18/50 [01:32<02:42,  5.09s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
#  36%|███▌      | 18/50 [01:34<02:48,  5.26s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/mlauber/mci_mri_graph/construct_ggm/pop_ggm_bootstrap_mikegvm.ipynb Cell 53 in 8
#       <a href='vscode-notebook-cell://ssh-remote%2Becho.bumc.bu.edu/home/mlauber/mci_mri_graph/construct_ggm/pop_ggm_bootstrap_mikegvm.ipynb#Y103sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> for nacc_bootstrap_sample in tqdm(nacc_bootstrap_samples):
#       <a href='vscode-notebook-cell://ssh-remote%2Becho.bumc.bu.edu/home/mlauber/mci_mri_graph/construct_ggm/pop_ggm_bootstrap_mikegvm.ipynb#Y103sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     nacc_model = GraphicalLassoCV(cv=2,max_iter=50, tol=1e-3)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Becho.bumc.bu.edu/home/mlauber/mci_mri_graph/construct_ggm/pop_ggm_bootstrap_mikegvm.ipynb#Y103sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     nacc_model.fit(nacc_bootstrap_sample)
#       <a href='vscode-notebook-cell://ssh-remote%2Becho.bumc.bu.edu/home/mlauber/mci_mri_graph/construct_ggm/pop_ggm_bootstrap_mikegvm.ipynb#Y103sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>     nacc_models.append(nacc_model)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:893, in GraphicalLassoCV.fit(self, X, y)
#     887     warnings.simplefilter("ignore", ConvergenceWarning)
#     888     # Compute the cross-validated loss on the current grid
#     889
#     890     # NOTE: Warm-restarting graphical_lasso_path has been tried,
#     891     # and this did not allow to gain anything
#     892     # (same execution time with or without).
# --> 893     this_path = Parallel(n_jobs=self.n_jobs, verbose=self.verbose)(
#     894         delayed(graphical_lasso_path)(
#     895             X[train],
#     896             alphas=alphas,
#     897             X_test=X[test],
#     898             mode=self.mode,
#     899             tol=self.tol,
#     900             enet_tol=self.enet_tol,
#     901             max_iter=int(0.1 * self.max_iter),
#     902             verbose=inner_verbose,
#     903         )
#     904         for train, test in cv.split(X, y)
#     905     )
#     907 # Little danse to transform the list in what we need
#     908 covs, _, scores = zip(*this_path)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/utils/parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:589, in graphical_lasso_path(X, alphas, cov_init, X_test, mode, tol, enet_tol, max_iter, verbose)
#     586 for alpha in alphas:
#     587     try:
#     588         # Capture the errors, and move on
# --> 589         covariance_, precision_ = graphical_lasso(
#     590             emp_cov,
#     591             alpha=alpha,
#     592             cov_init=covariance_,
#     593             mode=mode,
#     594             tol=tol,
#     595             enet_tol=enet_tol,
#     596             max_iter=max_iter,
#     597             verbose=inner_verbose,
#     598         )
#     599         covariances_.append(covariance_)
#     600         precisions_.append(precision_)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:210, in graphical_lasso(emp_cov, alpha, cov_init, mode, tol, enet_tol, max_iter, verbose, return_costs, eps, return_n_iter)
#     208 diagonal = emp_cov.flat[:: n_features + 1]
#     209 covariance_.flat[:: n_features + 1] = diagonal
# --> 210 precision_ = linalg.pinvh(covariance_)
#     212 indices = np.arange(n_features)
#     213 costs = list()
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/scipy/linalg/_basic.py:1411, in pinvh(a, atol, rtol, lower, return_rank, check_finite, cond, rcond)
#    1337 def pinvh(a, atol=None, rtol=None, lower=True, return_rank=False,
#    1338           check_finite=True, cond=None, rcond=None):
#    1339     """
#    1340     Compute the (Moore-Penrose) pseudo-inverse of a Hermitian matrix.
#    1341
#    (...)
#    1409
#    1410     """
# -> 1411     a = _asarray_validated(a, check_finite=check_finite)
#    1412     s, u = _decomp.eigh(a, lower=lower, check_finite=False)
#    1413     t = u.dtype.char.lower()
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/scipy/_lib/_util.py:287, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     285         raise ValueError('masked arrays are not supported')
#     286 toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 287 a = toarray(a)
#     288 if not objects_ok:
#     289     if a.dtype is np.dtype('O'):
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/lib/function_base.py:627, in asarray_chkfinite(a, dtype, order)
#     625 a = asarray(a, dtype=dtype, order=order)
#     626 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 627     raise ValueError(
#     628         "array must not contain infs or NaNs")
#     629 return a
#
# ValueError: array must not contain infs or NaNs

# %%
#check for nan or inf values - dont need anymore since I fixed it 
nacc_models = []
for nacc_bootstrap_sample in tqdm(nacc_bootstrap_samples):
    if nacc_bootstrap_sample.isnull().values.any() or np.isinf(nacc_bootstrap_sample).values.any():
        print('NaN or Inf found')
    nacc_model = GraphicalLassoCV(cv=2,max_iter=50, tol=1e-3)
    nacc_model.fit(nacc_bootstrap_sample)
    nacc_models.append(nacc_model)

#try logging 
import logging
logging.basicConfig(level=logging.INFO)


nacc_models = []
for idx, nacc_bootstrap_sample in enumerate(tqdm(nacc_bootstrap_samples)):
    # Check for NaN/Inf values
    if nacc_bootstrap_sample.isnull().values.any() or np.isinf(nacc_bootstrap_sample).values.any():
        logging.info(f'NaN or Inf found in sample {idx}')

    # Try to fit the model
    #try and except block structure 
    try:
        nacc_model = GraphicalLassoCV(cv=2, max_iter=50, tol=1e-3)
        nacc_model.fit(nacc_bootstrap_sample)
        nacc_models.append(nacc_model)
    except ValueError as e:
        logging.error(f'Error encountered in sample {idx}: {e}')
        logging.error(f'Data: {nacc_bootstrap_sample}')
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   2%|▏         | 1/50 [00:05<04:16,  5.24s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   4%|▍         | 2/50 [00:09<03:37,  4.53s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   6%|▌         | 3/50 [00:14<03:52,  4.95s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   8%|▊         | 4/50 [00:19<03:45,  4.90s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  10%|█         | 5/50 [00:25<04:00,  5.35s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  12%|█▏        | 6/50 [00:30<03:47,  5.16s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  14%|█▍        | 7/50 [00:36<03:48,  5.31s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  16%|█▌        | 8/50 [00:41<03:43,  5.32s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  18%|█▊        | 9/50 [00:45<03:28,  5.08s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  20%|██        | 10/50 [00:51<03:22,  5.06s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  22%|██▏       | 11/50 [00:56<03:19,  5.11s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  24%|██▍       | 12/50 [01:01<03:11,  5.04s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  26%|██▌       | 13/50 [01:06<03:07,  5.07s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  28%|██▊       | 14/50 [01:11<03:07,  5.22s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  30%|███       | 15/50 [01:16<02:59,  5.14s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  32%|███▏      | 16/50 [01:21<02:54,  5.14s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  34%|███▍      | 17/50 [01:27<02:51,  5.21s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  36%|███▌      | 18/50 [01:31<02:41,  5.06s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
#  36%|███▌      | 18/50 [01:34<02:47,  5.25s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/mlauber/mci_mri_graph/construct_ggm/pop_ggm_bootstrap_mikegvm.ipynb Cell 54 in 7
#       <a href='vscode-notebook-cell://ssh-remote%2Becho.bumc.bu.edu/home/mlauber/mci_mri_graph/construct_ggm/pop_ggm_bootstrap_mikegvm.ipynb#Y104sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>         print('NaN or Inf found')
#       <a href='vscode-notebook-cell://ssh-remote%2Becho.bumc.bu.edu/home/mlauber/mci_mri_graph/construct_ggm/pop_ggm_bootstrap_mikegvm.ipynb#Y104sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     nacc_model = GraphicalLassoCV(cv=2,max_iter=50, tol=1e-3)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Becho.bumc.bu.edu/home/mlauber/mci_mri_graph/construct_ggm/pop_ggm_bootstrap_mikegvm.ipynb#Y104sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     nacc_model.fit(nacc_bootstrap_sample)
#       <a href='vscode-notebook-cell://ssh-remote%2Becho.bumc.bu.edu/home/mlauber/mci_mri_graph/construct_ggm/pop_ggm_bootstrap_mikegvm.ipynb#Y104sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     nacc_models.append(nacc_model)
#      <a href='vscode-notebook-cell://ssh-remote%2Becho.bumc.bu.edu/home/mlauber/mci_mri_graph/construct_ggm/pop_ggm_bootstrap_mikegvm.ipynb#Y104sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> #try logging
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:893, in GraphicalLassoCV.fit(self, X, y)
#     887     warnings.simplefilter("ignore", ConvergenceWarning)
#     888     # Compute the cross-validated loss on the current grid
#     889
#     890     # NOTE: Warm-restarting graphical_lasso_path has been tried,
#     891     # and this did not allow to gain anything
#     892     # (same execution time with or without).
# --> 893     this_path = Parallel(n_jobs=self.n_jobs, verbose=self.verbose)(
#     894         delayed(graphical_lasso_path)(
#     895             X[train],
#     896             alphas=alphas,
#     897             X_test=X[test],
#     898             mode=self.mode,
#     899             tol=self.tol,
#     900             enet_tol=self.enet_tol,
#     901             max_iter=int(0.1 * self.max_iter),
#     902             verbose=inner_verbose,
#     903         )
#     904         for train, test in cv.split(X, y)
#     905     )
#     907 # Little danse to transform the list in what we need
#     908 covs, _, scores = zip(*this_path)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/utils/parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:589, in graphical_lasso_path(X, alphas, cov_init, X_test, mode, tol, enet_tol, max_iter, verbose)
#     586 for alpha in alphas:
#     587     try:
#     588         # Capture the errors, and move on
# --> 589         covariance_, precision_ = graphical_lasso(
#     590             emp_cov,
#     591             alpha=alpha,
#     592             cov_init=covariance_,
#     593             mode=mode,
#     594             tol=tol,
#     595             enet_tol=enet_tol,
#     596             max_iter=max_iter,
#     597             verbose=inner_verbose,
#     598         )
#     599         covariances_.append(covariance_)
#     600         precisions_.append(precision_)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:210, in graphical_lasso(emp_cov, alpha, cov_init, mode, tol, enet_tol, max_iter, verbose, return_costs, eps, return_n_iter)
#     208 diagonal = emp_cov.flat[:: n_features + 1]
#     209 covariance_.flat[:: n_features + 1] = diagonal
# --> 210 precision_ = linalg.pinvh(covariance_)
#     212 indices = np.arange(n_features)
#     213 costs = list()
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/scipy/linalg/_basic.py:1411, in pinvh(a, atol, rtol, lower, return_rank, check_finite, cond, rcond)
#    1337 def pinvh(a, atol=None, rtol=None, lower=True, return_rank=False,
#    1338           check_finite=True, cond=None, rcond=None):
#    1339     """
#    1340     Compute the (Moore-Penrose) pseudo-inverse of a Hermitian matrix.
#    1341
#    (...)
#    1409
#    1410     """
# -> 1411     a = _asarray_validated(a, check_finite=check_finite)
#    1412     s, u = _decomp.eigh(a, lower=lower, check_finite=False)
#    1413     t = u.dtype.char.lower()
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/scipy/_lib/_util.py:287, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     285         raise ValueError('masked arrays are not supported')
#     286 toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 287 a = toarray(a)
#     288 if not objects_ok:
#     289     if a.dtype is np.dtype('O'):
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/lib/function_base.py:627, in asarray_chkfinite(a, dtype, order)
#     625 a = asarray(a, dtype=dtype, order=order)
#     626 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 627     raise ValueError(
#     628         "array must not contain infs or NaNs")
#     629 return a
#
# ValueError: array must not contain infs or NaNs

# %%
# need anymore I fixed the issue 
import logging
from tqdm import tqdm
import pandas as pd
from sklearn.covariance import GraphicalLassoCV

logging.basicConfig(level=logging.INFO)

nacc_models = []
for idx, nacc_bootstrap_sample in enumerate(tqdm(nacc_bootstrap_samples)):
    # Locate NaN and Inf values
    nan_locations = nacc_bootstrap_sample.isnull().stack()[lambda x: x]
    inf_locations = nacc_bootstrap_sample.isin([np.inf, -np.inf]).stack()[lambda x: x]

    if not nan_locations.empty or not inf_locations.empty:
        logging.info(f'NaN or Inf found in sample {idx}')
        for location in nan_locations.index:
            logging.info(f'NaN found at row {location[0]}, column {location[1]}')
        for location in inf_locations.index:
            logging.info(f'Inf found at row {location[0]}, column {location[1]}')

    # Try to fit the model
    try:
        nacc_model = GraphicalLassoCV(cv=2, max_iter=50, tol=1e-3)
        nacc_model.fit(nacc_bootstrap_sample)
        nacc_models.append(nacc_model)
    except ValueError as e:
        logging.error(f'Error encountered in sample {idx}: {e}')
        logging.error(f'Data: {nacc_bootstrap_sample}')
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   2%|▏         | 1/50 [00:05<04:25,  5.43s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   4%|▍         | 2/50 [00:10<04:00,  5.02s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   6%|▌         | 3/50 [00:15<04:06,  5.25s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#   8%|▊         | 4/50 [00:20<04:01,  5.25s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  10%|█         | 5/50 [00:26<04:06,  5.48s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  12%|█▏        | 6/50 [00:31<03:52,  5.28s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  14%|█▍        | 7/50 [00:37<03:49,  5.35s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  16%|█▌        | 8/50 [00:42<03:41,  5.27s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  18%|█▊        | 9/50 [00:47<03:32,  5.19s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  20%|██        | 10/50 [00:53<03:36,  5.40s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  22%|██▏       | 11/50 [00:58<03:26,  5.29s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  24%|██▍       | 12/50 [01:03<03:24,  5.38s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  26%|██▌       | 13/50 [01:09<03:18,  5.36s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  28%|██▊       | 14/50 [01:14<03:09,  5.28s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  30%|███       | 15/50 [01:18<02:57,  5.08s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  32%|███▏      | 16/50 [01:23<02:51,  5.05s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  34%|███▍      | 17/50 [01:28<02:45,  5.00s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  36%|███▌      | 18/50 [01:33<02:38,  4.96s/it]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:893, in GraphicalLassoCV.fit(self, X, y)
#     887     warnings.simplefilter("ignore", ConvergenceWarning)
#     888     # Compute the cross-validated loss on the current grid
#     889
#     890     # NOTE: Warm-restarting graphical_lasso_path has been tried,
#     891     # and this did not allow to gain anything
#     892     # (same execution time with or without).
# --> 893     this_path = Parallel(n_jobs=self.n_jobs, verbose=self.verbose)(
#     894         delayed(graphical_lasso_path)(
#     895             X[train],
#     896             alphas=alphas,
#     897             X_test=X[test],
#     898             mode=self.mode,
#     899             tol=self.tol,
#     900             enet_tol=self.enet_tol,
#     901             max_iter=int(0.1 * self.max_iter),
#     902             verbose=inner_verbose,
#     903         )
#     904         for train, test in cv.split(X, y)
#     905     )
#     907 # Little danse to transform the list in what we need
#     908 covs, _, scores = zip(*this_path)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/utils/parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:589, in graphical_lasso_path(X, alphas, cov_init, X_test, mode, tol, enet_tol, max_iter, verbose)
#     586 for alpha in alphas:
#     587     try:
#     588         # Capture the errors, and move on
# --> 589         covariance_, precision_ = graphical_lasso(
#     590             emp_cov,
#     591             alpha=alpha,
#     592             cov_init=covariance_,
#     593             mode=mode,
#     594             tol=tol,
#     595             enet_tol=enet_tol,
#     596             max_iter=max_iter,
#     597             verbose=inner_verbose,
#     598         )
#     599         covariances_.append(covariance_)
#     600         precisions_.append(precision_)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:282, in graphical_lasso(emp_cov, alpha, cov_init, mode, tol, enet_tol, max_iter, verbose, return_costs, eps, return_n_iter)
#     278     raise FloatingPointError(
#     279         "The system is too ill-conditioned for this solver"
#     280     )
#     281 d_gap = _dual_gap(emp_cov, precision_, alpha)
# --> 282 cost = _objective(emp_cov, precision_, alpha)
#     283 if verbose:
#     284     print(
#     285         "[graphical_lasso] Iteration % 3i, cost % 3.2e, dual gap %.3e"
#     286         % (i, cost, d_gap)
#     287     )
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:44, in _objective(mle, precision_, alpha)
#      37 """Evaluation of the graphical-lasso objective function
#      38
#      39 the objective function is made of a shifted scaled version of the
#      40 normalized log-likelihood (i.e. its empirical mean over the samples) and a
#      41 penalisation term to promote sparsity
#      42 """
#      43 p = precision_.shape[0]
# ---> 44 cost = -2.0 * log_likelihood(mle, precision_) + p * np.log(2 * np.pi)
#      45 cost += alpha * (np.abs(precision_).sum() - np.abs(np.diag(precision_)).sum())
#      46 return cost
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_empirical_covariance.py:45, in log_likelihood(emp_cov, precision)
#      25 """Compute the sample mean of the log_likelihood under a covariance model.
#      26
#      27 Computes the empirical expected log-likelihood, allowing for universal
#    (...)
#      42     Sample mean of the log-likelihood.
#      43 """
#      44 p = precision.shape[0]
# ---> 45 log_likelihood_ = -np.sum(emp_cov * precision) + fast_logdet(precision)
#      46 log_likelihood_ -= p * np.log(2 * np.pi)
#      47 log_likelihood_ /= 2.0
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/utils/extmath.py:117, in fast_logdet(A)
#      84 def fast_logdet(A):
#      85     """Compute logarithm of determinant of a square matrix.
#      86
#      87     The (natural) logarithm of the determinant of a square matrix
#    (...)
#     115     3.6375861597263857
#     116     """
# --> 117     sign, ld = np.linalg.slogdet(A)
#     118     if not sign > 0:
#     119         return -np.inf
#
# File <__array_function__ internals>:180, in slogdet(*args, **kwargs)
#
# File /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/linalg/linalg.py:2094, in slogdet(a)
#    2092 real_t = _realType(result_t)
#    2093 signature = 'D->Dd' if isComplexType(t) else 'd->dd'
# -> 2094 sign, logdet = _umath_linalg.slogdet(a, signature=signature)
#    2095 sign = sign.astype(result_t, copy=False)
#    2096 logdet = logdet.astype(real_t, copy=False)
#
# KeyboardInterrupt:

# %%
#so there is one model that is throwing off the whole code in this 
print(len(nacc_models))
# Out:
# 100

# %%
#calc metrics - I think it was calcing the adni prog one (but they still look the same)
# iterating through each bootsrap sample model, calculating the graph metrics, and then storing the metrics for eahc model in a dataframe 
nacc_metrics_data = []

#keep track of index with enumerate 
for nacc_model_num, nacc_model in enumerate(nacc_models,start=1):
    nacc_precision_matrix_p = nacc_model.precision_
    np.fill_diagonal(nacc_precision_matrix_p, 0) #removes self connections by replacing the diagnonal of matrix with 0 
    nacc_G_prog = nx.Graph(nacc_precision_matrix_p)
    nacc_node_labels = {i: label for i, label in enumerate(nacc_progs_norm.columns)}
    #relabel the nodes in the graph using the dictionary
    nacc_G_prog = nx.relabel_nodes(nacc_G_prog, nacc_node_labels)
    #now calculate the metrics and store them 
    nacc_gpe = nx.global_efficiency(nacc_G_prog) 
    nacc_clustering_coefficient = nx.average_clustering(nacc_G_prog)
    nacc_density = nx.density(nacc_G_prog)
    # eigen_cen = nx.eigenvector_centrality(G_prog)
    nacc_ass_coeff = nx.degree_assortativity_coefficient(nacc_G_prog)
    # diameter = nx.diameter(G_prog)
    # radius = nx.radius(G_prog)


    #create dictionary for current models data 
    nacc_metrics_dic = {
        'model_num': nacc_model_num,
        'gpe': nacc_gpe,
        'clus_coeff':nacc_clustering_coefficient,
        'density': nacc_density,
        'ass_coeff': nacc_ass_coeff
    }
    nacc_metrics_data.append(nacc_metrics_dic)


#turn the list of dictionaries with each model info into a df
nacc_metrics_data = pd.DataFrame(nacc_metrics_data)
nacc_metrics_data.to_csv('/data2/MRI_PET_DATA/graph/csvs/bootstrap_models_and_metrics/full_bootstrap_models_prog_metrics_nacc.csv')
# print(metrics_data.dtypes)
print(nacc_metrics_data.shape)
# Out:
# (100, 5)

# %%
#nacc_gmv_stab
#run bootstrap for stable df 
np.random.seed(3)
nacc_stab_num_bootstrap_samples = 100
nacc_stab_bootstrap_precision_matrices = []
nacc_stab_bootstrap_samples = []
for x in range(nacc_stab_num_bootstrap_samples):
    #sample with replacement, randomstate =1 for reporoducibility 
    nacc_stab_bootstrap_sample = stable_norm.sample(n=len(stable_norm),replace=True)
    #append resamples df to a list 
    nacc_stab_bootstrap_samples.append(nacc_stab_bootstrap_sample)

# %%
#run graphical model on bootstrapped sample 
nacc_stab_models = []
for nacc_stab_bootstrap_sample in tqdm(nacc_stab_bootstrap_samples):
    #if I give it alphas [1,10] it looks like it drops almost all of the connections 
    
    nacc_stab_model = GraphicalLassoCV(cv=2,max_iter=50,tol=1e-3)
    nacc_stab_model.fit(nacc_stab_bootstrap_sample)
    nacc_stab_models.append(nacc_stab_model)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]/data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:272: RuntimeWarning: invalid value encountered in multiply
#   precision_[indices != idx, idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#
x] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/sklearn/covariance/_graph_lasso.py:273: RuntimeWarning: invalid value encountered in multiply
#   precision_[idx, indices != idx] = -precision_[idx, idx] * coefs
# /data2/MRI_PET_DATA/graph/graph_env/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# 100%|██████████| 100/100 [08:50<00:00,  5.30s/it]

# %%
print(len(nacc_stab_models))
# Out:
# 100

# %%
# Assuming stable_norm and stab_models are already defined somewhere

nacc_stab_metrics_data = []

for nacc_model_num, nacc_stab_model in enumerate(nacc_stab_models):
    nacc_precision_matrix_stab = nacc_stab_model.precision_
    np.fill_diagonal(nacc_precision_matrix_stab, 0)  # removes self connections by replacing the diagonal of matrix with 0
    nacc_G_stab = nx.Graph(nacc_precision_matrix_stab)
    # create a dictionary that maps old node labels to new node labels
    naccstab_node_labels = {i: label for i, label in enumerate(nacc_stable_norm.columns)}
    # relabel the nodes in the graph using the dictionary
    nacc_G_stab = nx.relabel_nodes(nacc_G_stab, naccstab_node_labels)
    # now calculate the metrics and store them
    nacc_stab_gpe = nx.global_efficiency(nacc_G_stab)
    nacc_stab_clustering_coefficient = nx.average_clustering(nacc_G_stab)

    # Assuming you want to store metrics for stab (stability) models,
    # not prog (progression) models as shown in the second snippet
    nacc_stab_density = nx.density(nacc_G_stab)
    nacc_stab_ass_coeff = nx.degree_assortativity_coefficient(nacc_G_stab)

    # metrics dictionary
    nacc_stab_metrics_dic = {'model_num': nacc_model_num,
                        'gpe': nacc_stab_gpe,
                        'clus_coeff': nacc_stab_clustering_coefficient,
                        'density': nacc_stab_density,
                        'ass_coeff': nacc_stab_ass_coeff
                        }

    nacc_stab_metrics_data.append(nacc_stab_metrics_dic)

nacc_stab_metrics_data = pd.DataFrame(nacc_stab_metrics_data)
nacc_stab_metrics_data.to_csv('/data2/MRI_PET_DATA/graph/csvs/bootstrap_models_and_metrics/50_bootstrap_models_stab_metrics_nacc.csv')
print(nacc_stab_metrics_data)
# Out:
#     model_num       gpe  clus_coeff   density  ass_coeff
# 0           0  0.467661    0.409867  0.117740   0.230581
# 1           1  0.462437    0.432026  0.119539   0.185521
# 2           2  0.479908    0.392549  0.115836   0.189562
# 3           3  0.478471    0.390108  0.117529   0.213140
# 4           4  0.472795    0.388837  0.119221   0.251775
# 5           5  0.479869    0.410742  0.118587   0.188697
# 6           6  0.475600    0.376136  0.120808   0.267426
# 7           7  0.468026    0.396291  0.117211   0.224252
# 8           8  0.485735    0.372549  0.120702   0.176863
# 9           9  0.481422    0.406232  0.119539   0.163524
# 10         10  0.473791    0.393821  0.119645   0.225369
# 11         11  0.483372    0.376420  0.121126   0.220724
# 12         12  0.465711    0.421243  0.123453   0.186581
# 13         13  0.470424    0.375687  0.118375   0.274405
# 14         14  0.475870    0.392994  0.121549   0.232506
# 15         15  0.485290    0.406077  0.117211   0.219178
# 16         16  0.483007    0.395902  0.120808   0.162417
# 17         17  0.473541    0.374122  0.119539   0.212361
# 18         18  0.469549    0.397291  0.116154   0.224541
# 19         19  0.479275    0.393251  0.121020   0.182935
# 20         20  0.478492    0.377282  0.116259   0.220255
# 21         21  0.468151    0.401296  0.115413   0.194205
# 81         81  0.479060    0.421818  0.120702   0.202871
# 82         82  0.484703    0.391149  0.121337   0.229566
# 83         83  0.471549    0.386355  0.111711   0.181089
# 84         84  0.477402    0.355596  0.114461   0.204705
# 85         85  0.486315    0.393459  0.117211   0.199389
# 86         86  0.482848    0.390752  0.120702   0.172579
# 87         87  0.491091    0.383346  0.123453   0.165272
# 88         88  0.488242    0.399471  0.123559   0.178030
# 89         89  0.489109    0.391170  0.123664   0.203004
# 90         90  0.481734    0.364622  0.120702   0.188474
# 91         91  0.474498    0.376616  0.119750   0.224074
# 92         92  0.466247    0.361088  0.112134   0.185121
# 93         93  0.489053    0.370769  0.123136   0.173142
# 94         94  0.478781    0.396925  0.122501   0.152053
# 95         95  0.490022    0.367348  0.117952   0.159749
# 96         96  0.476036    0.399135  0.116788   0.187328
# 97         97  0.482300    0.381992  0.119750   0.224187
# 98         98  0.479310    0.368347  0.116577   0.223127
# 99         99  0.477728    0.396202  0.122289   0.197124

# %%
#
print(nacc_metrics_data.shape)
print(nacc_stab_metrics_data.shape)
# Out:
# (100, 5)
# (100, 5)

# %%
#nacc t test 
#instead of calcing mean just calc from data instead 
#add col where the p val is greater than .05

# Initialize lists or a DataFrame to store your results
cols = []
p_values = []
t_stats = []

# Note: The dataframe should be adni_gmv_progs, not adni_gmv_prog
for col in nacc_metrics_data.columns:  
    if col != 'model_num':
    # Get data for this brain region from both datasets
        nacc_progs_data = nacc_metrics_data[col]
        nacc_stab_data = nacc_stab_metrics_data[col]
        
        # Perform t-test
        t_stat, p_val = stats.ttest_ind(nacc_progs_data, nacc_stab_data, equal_var=False)  # Assuming variance might not be equal
        
        # Store results
        cols.append(col)
        t_stats.append(t_stat)
        p_values.append(p_val)

    # Combine results into a DataFrame for easy viewing and further analysis
    nacc_results_df = pd.DataFrame({
        'Brain Region': cols,
        'T-Statistic': t_stats,
        'P-Value': p_values
})

# Adding the Significant column based on the P-Value
nacc_results_df['Significant'] = nacc_results_df['P-Value'] < 0.05

# Display or save the results
print("Nacc t test results between nacc prog and nacc stab")
print(nacc_results_df)
# Optionally save to a CSV file
# results_df.to_csv('t_test_results.csv', index=False)

#the resulting negative t stats mean the progs have lower volume than the stab which is good 
nacc_results_df.to_csv('/data2/MRI_PET_DATA/graph/csvs/bootstrap_models_and_metrics/50_bootstrap_models_ttest_nacc.csv')
# Out:
# Nacc t test results between nacc prog and nacc stab
#   Brain Region  T-Statistic       P-Value  Significant
# 0          gpe   -11.130935  2.870134e-19         True
# 1   clus_coeff    -2.696797  7.854546e-03         True
# 2      density    -9.305936  2.348927e-15         True
# 3    ass_coeff    -8.811971  8.721287e-15         True

# %%
print("Adni t test results between adni prog and adni stab")
print(results_df)
#andi and nacc results are the exact same so need to figure out why they are not
# Out:
# Adni t test results between adni prog and adni stab
#   Brain Region  T-Statistic       P-Value  Significant
# 0          gpe    -6.349198  3.268807e-09         True
# 1   clus_coeff   -22.606128  9.647343e-57         True
# 2      density   -27.292662  1.028930e-63         True
# 3    ass_coeff    -5.030910  1.270020e-06         True
